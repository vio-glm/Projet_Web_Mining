# %% [markdown]
# IMPORT IMPLEMENTATION

# %%
from bertopic import BERTopic
from bs4 import BeautifulSoup
from collections import Counter, deque
import csv
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
import os
import pandas as pd
import random
import re 
import requests
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import string
import time
import token 
from urllib.parse import urljoin, urlparse, unquote

# %%
nltk.download('punkt')
nltk.download('punkt_tab') # Nécessaire pour les nouvelles versions
nltk.download('wordnet')
nltk.download('omw-1.4')   # Souvent requis par le lemmatizer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# IMPLEMENTATION OF CONSTANTS

# %%
# --- CONFIGURATION OF COLORS ---

GREEN = "\033[92m"
RED = "\033[91m"
YELLOW = "\033[93m"
BLUE = "\033[94m"
RESET = "\033[0m"

# %%
# --- CONFIGURATION OF HEADERS ---

HEADER_BROWSER = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.0.0",
    "Accept-Language": "en-US,en;q=0.5",
    "Referer": "https://www.google.com/"}

session = requests.Session()
session.headers.update(HEADER_BROWSER)

# %%
# --- CONFIGURATION OF FILTERS ---

filters_noise = [
    "/product", "/products", "/shop", "/store", "/cart", "/checkout",
    "/account", "/login", "/register", "/tag", "/search",
    "/about", "contact", "privacy", "terms", "#",
    "mailto:", "tel:", "javascript:",
    ".jpg", ".png", "accessibility", "editorial-process",
    "data-collection", "disclaimer", "wc", "sponsor",
    "youtube.com", "instagram.com", "facebook.com", "twitter.com",
    "pinterest.com", "linkedin.com", "tiktok.com", "amazon.com"
]

# %%
# --- CONFIGURATION OF SEED LINKS FOR WIKIPEDIA ---

wiki_seed_pages = [ # Our selection of a few pages = starting list
    "https://en.wikipedia.org/wiki/Lifestyle",
    "https://en.wikipedia.org/wiki/Lifestyle_trends_and_media",
    "https://en.wikipedia.org/wiki/Self-care",
    "https://en.wikipedia.org/wiki/Physical_fitness",
    "https://en.wikipedia.org/wiki/Healthy_diet",
    "https://en.wikipedia.org/wiki/Travel",
    "https://en.wikipedia.org/wiki/Outdoor_recreation",
    "https://en.wikipedia.org/wiki/Sustainable_living",
    "https://en.wikipedia.org/wiki/Fashion",
]

# %% [markdown]
# IMPLEMENTATION OF DEFINITIONS

# %%
def get_filenames(source_name):
    directory_name = "data"
    if not os.path.exists(directory_name):
            os.makedirs(directory_name)
            print(f"{GREEN}Created directory : {directory_name}{RESET}")
    
    # Avertissement si écrasement (juste pour info)
    if os.path.exists(source_name):
        print(f"{BLUE}Note : The file is overwritten{RESET}") 
    
    base_name = source_name.replace(" ", "_")

    return {"raw":       os.path.join(directory_name, f"{base_name}_raw_html.csv"),
            "corpus":    os.path.join(directory_name, f"{base_name}_corpus.csv"),
            "cleaned":   os.path.join(directory_name, f"{base_name}_cleaned.csv"),
            "norm":      os.path.join(directory_name, f"{base_name}_corpus_norm.csv"),
            "tokenized": os.path.join(directory_name, f"{base_name}_corpus_tokenized.csv"),
            "nodes" :    os.path.join(directory_name, f"{base_name}_nodes.csv"),
            "edges" :    os.path.join(directory_name, f"{base_name}_edges.csv")}

# %%
def fetch_url(url) :

    time.sleep(random.uniform(1, 3)) 

    try:
        response = session.get(url, timeout=10)
        if response.status_code == 200: 
            return response # If the status code is not OK (200) the function return none and an error message
        else:
            print(f"Failed to fetch the url: {url} with status code {response.status_code}")
            return None
    
    except requests.RequestException:
        return None

# %%
def to_soup(url):
    response = fetch_url(url)
    if response:  # If the response is not none, the function return the beautiful soup object
        return BeautifulSoup(response.text, 'html.parser') 
    else:
        return None

# %%
def extract_links_breadth_first(url, max_levels=1): 
    queue = deque([(url, 0)])
    visited_links = [url]  # liste pour garder l'ordre
    last_level_links = []
    start_domain = urlparse(url).netloc
    dico = {}

    while queue:
        current_url, current_level = queue.popleft()

        if current_level == max_levels:
            if current_url not in last_level_links:
                last_level_links.append(current_url)
            continue
        elif current_level > max_levels:
            continue
    
        soup = to_soup(current_url)
        if not soup:
            continue

        dico.setdefault(current_url, [])

        content_area = soup.body # Stay large (here) to get more links
        if not content_area:
            continue
        links = sorted(content_area.find_all('a', href=True), key=lambda x: x.get('href'))
        
        for item in links :
            href = item.get('href')

            full_url = urljoin(current_url, href)
            full_url = full_url.split('?')[0].split('#')[0]
            full_url = full_url.lower()

            # Si nouveau lien trouvé
            if any(filter in full_url for filter in filters_noise):
                continue
            
            dico[current_url].append(full_url)

            if full_url not in visited_links:
                visited_links.append(full_url)
                queue.append((full_url, current_level + 1))
                    
    return visited_links, last_level_links, dico

# %%
def extract_links_depth_first(start_url, visited_links, dico, max_depth=3, max_links_per_page=10, current_depth=0):
    if current_depth >= max_depth:
        return

    soup = to_soup(start_url)
    if not soup :
        return

    dico.setdefault(start_url, [])
    links_followed = 0

    content_area = soup.body
    if not content_area:
        return
    
    links = sorted(content_area.find_all('a', href=True), key=lambda x: x.get('href'))
    for item in links:
        if links_followed >= max_links_per_page:
            break

        href = item.get('href')

        full_url = urljoin(start_url, href)
        full_url = full_url.split('?')[0].split('#')[0]
        full_url = full_url.lower()

        if any(filter in full_url for filter in filters_noise):
                continue

        dico[start_url].append(full_url)

        if full_url not in visited_links:
            visited_links.append(full_url)
            links_followed += 1
            extract_links_depth_first( start_url=full_url, visited_links=visited_links, dico=dico, max_depth=max_depth, max_links_per_page=max_links_per_page, current_depth=current_depth + 1)
    return visited_links, dico
# Out:
#   Cell In[1], line 36
#     current_depth=current_depth += 1
#                                 ^
# SyntaxError: invalid syntax

# %%
def extract_links_depth_from_list(start_links, visited_links, dico, max_depth=3, max_links_per_page=10):
    if visited_links is None:
        visited_links = []
    
    # Ajouter les liens de départ au set des déjà visités
    for link in sorted(start_links):
        if link not in visited_links:
            visited_links.append(link)

    for start_url in sorted(start_links)[:max_links_per_page]:
        extract_links_depth_first( start_url=start_url, visited_links=visited_links, dico=dico, max_depth=max_depth, max_links_per_page=max_links_per_page, current_depth=0)

    return visited_links

# %%
def crawl_MBG_seed_links(url):
    # Paramètres fixes
    MAX_BREADTH_LEVEL = 2
    MAX_DEPTH = 2
    MAX_LINKS_PER_PAGE = 10

    # Crawl en largeur
    breadth_links, last_level_links, dico = extract_links_breadth_first(url, max_levels=MAX_BREADTH_LEVEL)

    # Crawl en profondeur à partir des liens du dernier niveau
    depth_links = extract_links_depth_from_list( start_links=last_level_links, visited_links=breadth_links.copy(), dico=dico, max_depth=MAX_DEPTH, max_links_per_page=MAX_LINKS_PER_PAGE)

    # Retourne tous les liens uniques sous forme de liste
    all_links = set(breadth_links) | set(depth_links)
    return list(all_links), dico

# %%
def extract_wikipedia_links(url):
    soup = to_soup(url)
    if not soup:
        return set()

    wiki_links = set()

    # --- Main content ---
    main_content = soup.find_all('div', class_="mw-content-ltr mw-parser-output")
    for div in main_content:
        for p in div.find_all('p'):
            for item in p.find_all('a', href=True):
                href = item.get('href')
                if href.startswith("/wiki/") and ":" not in href:
                    wiki_links.add(urljoin(url, href))

    # --- See also section ---
    see_also = soup.find_all('div', class_='div-col')
    for div in see_also:
        for li in div.find_all('li'):
            for item in li.find_all('a', href=True):
                href = item.get('href')
                if href.startswith("/wiki/") and ":" not in href:
                    wiki_links.add(urljoin(url, href))

    return list(wiki_links)

# %%
def crawl_wiki_seed_links(wiki_seed_pages):
    wiki_all_links = set(wiki_seed_pages) # Set() avoids duplication, unlike lists
    dico_wiki_links = {}
    for url in wiki_seed_pages:
        crawl_links = extract_wikipedia_links(url)
        dico_wiki_links[url] = crawl_links
        wiki_all_links.update(crawl_links) # Only add new links

    return list(wiki_all_links), dico_wiki_links

# %%
def save_to_csv(data, filename):
    
    if not data:
        print(f"{RED}No data to save.{RESET}")
        return

    if not os.path.exists(filename):
        print(f"{RED}Error: File {filename} was not created")
 
    # Get the keys from the first dictionary for the CSV header from get_html_content
    fieldnames = data[0].keys() # Detection of the existing colons in the data file
    
    try:
        with open(filename, 'w', newline='', encoding='utf-8') as f: # Opens the csv file as utf-8
            writer = csv.DictWriter(f, fieldnames=fieldnames, quoting=csv.QUOTE_ALL) # Initialising a writer to write the dictionary into the csv file
            writer.writeheader() # writes the colons headers
            writer.writerows(data) # writes the rows
        print(f"{GREEN}Success! Data saved to: {RESET}{os.path.abspath(filename)}")
        
    except Exception as e:
        print(f"{RED}Error saving file: {e}{RESET}")

# %% [markdown]
# retirer le max=None et links[:max] pour run tout

# %%
def get_html_content(links, output_csv, max=None):
    content = []
    failed_links = []

    for link in links[:max]:
        response = fetch_url(link)
        if response:
            content.append({'url': link, 'html': response.text})
        else:
            failed_links.append(link)

    print(f"{GREEN}Fetched: {len(content)}{RESET}")
    print(f"{RED}Failed: {len(failed_links)}{RESET}")

    if output_csv and content:
        save_to_csv(content, output_csv)

    return content, failed_links

# %% [markdown]
# Préparation au link analysis

# %%
def create_nodes_csv(all_links, output_file="nodes.csv"):
    nodes = set(all_links.keys())  # Each key of the dictionnary "all_links" is a node (we don't keep any possible duplicate)
    for targets in all_links.values():
        nodes.update(targets)  # Each value of the dictionnary is a node

    with open(output_file, mode="w", newline="", encoding="utf-8") as f:  # Create (or open) a csv file 
        writer = csv.writer(f)  # Create an object that will enable our code to write within the file
        writer.writerow(["node_id"])
        for node in nodes:
            writer.writerow([node])

# %%
def create_edges_csv(links, output_file="edges.csv"):
    
    with open(output_file, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["source", "target"])  # We start by writing the headers of our column

        for source, targets in links.items():
            for target in targets:  # Mettre "set(targets)"" si je veux éviter les doublons (A -> B), il comprend bien que A -> B x=x B -> A donc tkt
                # A ajouter / tester (devrait empecher les boucles infines)
                if target != source:  
                    writer.writerow([source, target])  # If the target is different form the source (not A -> A), we add the relation in our file
                else :
                    continue

# %% [markdown]
# CONFIGURATION

# %%
sources = [
    {"name": "MBG",
     "start_url": "https://www.mindbodygreen.com/",
     "crawler_func": crawl_MBG_seed_links,
     "output_file": "data/MBG.csv"},  # We pass the specific function without calling it ()
    {"name": "wiki",
     "start_url": wiki_seed_pages,
     "crawler_func": crawl_wiki_seed_links,
     "output_file": "data/wiki.csv"}
    ]

# %% [markdown]
# EXECUTION

# %%
"""========================== SOURCES PIPELINE =========================="""

"""=== SETUP ==="""
for source in sources:
    #filename = source["output_file"]
    source_name = source["name"]
    start_point = source["start_url"]

    files = get_filenames(source_name)


    print(f"=== SOURCE TRAITEMENT : {source_name} ===")

    
    print("\n=== CRAWLING ===")

    print(f"{BLUE}[{source_name}] Starting the crawling...{RESET}")    
    crawled_links, dico_links = source["crawler_func"](start_point) # Ex : crawled_links = extract_website_links(https://....)
    print(f"-> Found {len(crawled_links)} links")

   
    print("\n=== SCRAPING ===")
    
    print(f"{BLUE}[{source_name}] Starting the scraping...{RESET}")
    get_html_content((crawled_links), files['raw'])
    print(f"{GREEN}Raw HTML data saved to {files['raw']}{RESET}")
    

    print("\n=== CREATE CSV OF NODES ===")

    print(f"{BLUE}[{source_name}] Creating nodes CSV...{RESET}")
    # Ici on transforme la liste de liens en dictionnaire {url: []} pour être compatible
    create_nodes_csv(dico_links, output_file=files['nodes'])
    print(f"{GREEN}Nodes CSV saved to {files['nodes']}{RESET}")

    print("\n=== CREATE CSV OF EDGES ===")
    print(f"{BLUE}[{source_name}] Creating edges CSV...{RESET}")
    create_edges_csv(dico_links, output_file=files['edges'])
    print(f"{GREEN}Edges CSV saved to {files['edges']}{RESET}")
# Out:
# === SOURCE TRAITEMENT : MBG ===
#
# === CRAWLING ===
# [MBG] Starting the crawling...
# Failed to fetch the url: https://bit.ly/cawalnutsgalette with status code 404
# Failed to fetch the url: https://bit.ly/cawalnutsswisschardsalad with status code 404
# Failed to fetch the url: https://bit.ly/cawalnutswellington with status code 404
# Failed to fetch the url: https://go.skimresources.com with status code 404
# -> Found 1032 links
#
# === SCRAPING ===
# [MBG] Starting the scraping...
# Failed to fetch the url: https://podcasts.apple.com/us/podcast/id1246494475/episodes with status code 500
# Failed to fetch the url: https://www.amjmed.com/article/s0002-9343(14)00138-7/fulltext with status code 403
# Failed to fetch the url: https://onlinelibrary.wiley.com/doi/10.1111/sms.70113 with status code 403
# Failed to fetch the url: https://pubmed.ncbi.nlm.nih.gov/28329045/ with status code 403
# Failed to fetch the url: https://karger.com/ger/article/62/2/138/149063/kicking-back-cognitive-ageing-leg-power-predicts with status code 403
# Failed to fetch the url: https://www.ncbi.nlm.nih.gov/pmc/articles/pmc3703169/ with status code 403
# Failed to fetch the url: https://bit.ly/cawalnutsswisschardsalad with status code 404
# Failed to fetch the url: https://pubmed.ncbi.nlm.nih.gov/21226679/ with status code 403
# Failed to fetch the url: https://bit.ly/cawalnutswellington with status code 404
# Failed to fetch the url: https://go.skimresources.com with status code 404
# Failed to fetch the url: https://www.mdpi.com/2076-3417/12/15/7523 with status code 403
# Failed to fetch the url: https://podcasts.apple.com/us/podcast/id1562146692/episodes with status code 500
# Failed to fetch the url: https://www.google.com/url with status code 404
# Failed to fetch the url: https://pmc.ncbi.nlm.nih.gov/articles/pmc10777545/ with status code 403
# Failed to fetch the url: https://bit.ly/cawalnutsgalette with status code 404
# Failed to fetch the url: https://pubmed.ncbi.nlm.nih.gov/19526369/ with status code 403
# Failed to fetch the url: https://www.glassdoor.com/salaries/health-coach-salary-srch_ko0,12.htm with status code 403
# Fetched: 1014
# Failed: 18
#  ERROR : File data\MBG_raw_html.csv was not created
# Success! Data saved to: c:\Users\Violaine\OneDrive\Ecole\Master 1\Web mining\Projet Web Mining\Projet_Web_Mining\Extraction\data\MBG_raw_html.csv
# Raw HTML data saved to data\MBG_raw_html.csv
#
# === CREATE CSV OF NODES ===
# [MBG] Creating nodes CSV...
# Nodes CSV saved to data\MBG_nodes.csv
#
# === CREATE CSV OF EDGES ===
# [MBG] Creating edges CSV...
# Edges CSV saved to data\MBG_edges.csv
# === SOURCE TRAITEMENT : wiki ===
#
# === CRAWLING ===
# [wiki] Starting the crawling...
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lifestyle_trends_and_media with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Outdoor_recreation with status code 403
# -> Found 898 links
#
# === SCRAPING ===
# [wiki] Starting the scraping...
# Failed to fetch the url: https://en.wikipedia.org/wiki/Leadership_in_Energy_and_Environmental_Design with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Geothermal_heat_pump with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Nitrogen_fertilizer with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Electric_grid with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Global_crisis with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gyrovague with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Washing_machines with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ethics_of_eating_meat with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sedentary_lifestyle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Abraham_Bosse with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Paris_Fashion_Week with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Street_style with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Social_support with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Macronutrient with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Recycling with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Football_shirt with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Madras_plaid with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bodymind with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Portuguese_people with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Machine_vision with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/David_L._Katz with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Processed_food with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Plant-based_diet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Recreation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Walkway with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_design with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Aerobic_exercise with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Social_health with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pinstripe with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_activism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Motif_(textile_arts) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Visa_(document) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Kimberly_Ovitz with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Baseball_jacket with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Summer_house with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Rainwater_harvesting with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Carbon_emissions with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Cardigan_sweater with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Passive_solar with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sufficiency_economy with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_house with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_Theory_(journal) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ecological_movement with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Black_feminism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_victim with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Arnold_Mitchell with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pierre_Cardin with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Leaching_(agriculture) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Style_(visual_arts) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Plant_growth_regulators with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Solar_cookers with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bill_de_Blasio with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Climate_change_mitigation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Straw-bale_construction with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Food_production with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Guillaume_de_Lorris with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ecodesign with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Landfill with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Nutrient_cycling with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Mental_health with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Platform_shoes with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lifestyle_(sociology) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/DETR with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fossil_fuels with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Organic_farming with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/List_of_LGBT_people_from_New_York_City#Drag with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Adherence_(medicine) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Market_research with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ephemerality with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Agriculture_pollution with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Environmental_impact_of_aviation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Indoor_air_quality with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Coral_pink with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Mass_media with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Western_shirt with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Water_table with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bike-sharing with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_industry with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Stover with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Low_flush_toilet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Aesthetics_(textile) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Resource_efficiency with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Preppy with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Alexis_Alford with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gucci with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pulse_oximeter with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ship with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dermatitis_herpetiformis with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/High_blood_pressure with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Weight_training with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Human_migration with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ethical_consumerism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Detergents with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Vitamin_B12 with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Insulating_concrete_form with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Roland_Barthes with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Capitalization_(disambiguation) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bioregionalism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Self-neglect with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Environmental_cost with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Beliefs with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Red_carpet_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Salmon_pink with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Product_analysis with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Overweight with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Vacuum_packing with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Trouser_suit with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Downshifting_(lifestyle) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Baroque with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Style_of_life with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Seat_belt_legislation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Jumpsuit with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Grass_fed with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bootcut with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Soil_degradation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Community_gardens with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gastrointestinal_cancer with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dupe_culture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bottling with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fitness_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Residential_garden with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Composting with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Endurance with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/List_of_nutrition_guides with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Volunteer_travel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Type_2_diabetes_mellitus with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Overspending with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_journalism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Roof-top_garden with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/French_Revolution with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Health_literacy with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Natural_resources with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Solar_distillation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_landscaping with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lifestyle_medicine with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Biological_pest_control with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Metabolic_rate with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Marina_DeBris with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Biomass_power with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Derrick_Jensen_(activist) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/NIH with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hot_flashes with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/USDA with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ugg_boot with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pilot with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Midriff with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Natural_fiber with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Baggy_pants with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bright_green_environmentalism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Seat_belt with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dorothea_Orem with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Children%27s_hospice with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Crop_rotation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Efficient_energy_use with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Mulch with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Influencers with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Raw_material with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Evidence-based_practice with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dress_code with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dietary_fibre with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Han_Chinese_clothing with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/1970s_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Self-sustainability with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_psychology with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Industrial_civilization with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Myokine with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Genroku_culture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Philosophy_of_self#Self-knowledge with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Nurse with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Cordwood_construction with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Steam_turbine with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Self-care_deficit_nursing_theory with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Airship with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Low-emissivity with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Milton_Rokeach with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Vegan_diet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Adventure_travel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Advanced_capitalism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Tailors%27_guilds with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Digital_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Media_culture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/PEST_analysis with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Life_stance with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Maxi_skirt with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Roof with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Radical_environmentalist with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Conventional with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Epileptic_seizures with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Kiosks with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Disease_burden with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Morbidity with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Physical_Activity_Guidelines_for_Americans with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hormones with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ischaemic_heart_disease with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Health with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Land_use with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Cochrane_review with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hypokinetic_diseases with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Diastolic_blood_pressure with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Xeriscaping with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Trends with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fossil_fuel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/New_York_City_Department_of_Housing_Preservation_and_Development with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/National_Organic_Standards_Board with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Water_runoff with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Committee_of_Advertising_Practice with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dehydration_(food) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Multimorbidity with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Marion_Nestle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hostile_Attribution_Bias with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Synthetic_fibers with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lifestyle_trends_and_media with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hip_hugger with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Railway with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Circles_of_Sustainability with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fetish_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Recreational_travel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Calorie_restriction with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Moorish_Spain with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/James_Laver with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/National_Heart_Foundation_of_Australia with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Stonewash with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Epimeleia_heautou with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Emotional_health with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Mission_trip with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Internal_passport with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_week with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Louis_XIV_style with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Food_choice with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Safety with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gluten-related_disorders with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Power_plant with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Advertising_mail with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Designer_clothing with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Rain_boot with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lifestyle_brand with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Science_tourism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Aristocrat with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Maxi_dress with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Chronic_disease with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Point_of_sale_display with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Recycle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Anti-fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Cob_(material) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/London_Fashion_Week with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Friar with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Demographics with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gap_Inc. with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Eco-communalism with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Duster_coat with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lester_R._Brown with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Freezing_(food) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Environmental_impact_of_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Native_plant with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Green_lifestyle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/La_Gazette_du_Bon_Ton with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Organic_material with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Carcinogenic with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Healthy_lifestyle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_forest_management with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Water_use with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Harvard_School_of_Public_Health with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Business_travel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Index_of_fashion_articles with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Transport_infrastructure with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Industrial_agriculture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/International_driving_permit with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Management_of_obesity with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lifestyle_guru with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Location_(geography) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Compressed_earth_block with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Depression_(mood) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Solar_cells with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/List_of_LGBT_people_from_New_York_City#Fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Baseball_jersey with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Slow_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/West_Africa with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Textile_industry with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/The_Root_(magazine) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Biogas with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Carrying_capacities with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Mass_production with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gilet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Dietary_Guidelines_for_Americans with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Androgynous with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Foodscaping with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Psychosocial with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Organic_certification with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Soil_pollution with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Flared_jeans with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Atmospheric_methane with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/World_view with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hans_Kraus with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Monoculture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Detox_diet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Social_marker with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Environmental_impact_of_meat_production with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Species with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Organic_agriculture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Endocrine_organ with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Community-supported_agriculture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Green_building with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fashion_faux_pas with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Green_energy with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Western_dress_codes with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Low-fat_diet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/1300%E2%80%931400_in_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ecovillages with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Cellulose_insulation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Electric_bicycles with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Aquamarine_(colour) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/House_work with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_event_management with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Gluten_ataxia with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/S%C3%A3o_Paulo_Fashion_Week with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Travel_itinerary with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/World_Cancer_Research_Fund with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Earth_Policy_Institute with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Food_additives with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Vasomotor with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Blood_pressure_cuff with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pesticide_application with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/FashionTV with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Roxy_Jacenko with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Carbon_output with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Clothing_industry with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pearl_snap with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Solar_water_heater with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Product_and_manufacturing_information with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Appropriate_technology with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/List_of_travelers with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Waste_reduction with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Habitat with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Microfiber with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_urban_drainage_systems with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Preventive_healthcare with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Reproductive_freedom with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Merchants with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Green_roofs with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Khorasan_wheat with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Product_placement with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Civil_and_political_rights with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Black_women with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/William_Dufty with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lime_render with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Hazardous_material with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Irrigation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Edible_landscaping with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Alternative_lifestyle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Systole with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Personal_life with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Low-carbohydrate_diet with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Obese with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Muscle_building with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Environmentalist with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Climate-friendly_gardening with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Lynn_R._Kahle with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Traveling_minstrel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/American_Institute_for_Cancer_Research with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Energy_Star with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Medieval_times with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Clay with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Daniel_Yankelovich with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Straight_leg_jeans with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Modest_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Recyclable_packaging with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Bourgeoisie with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Toilets with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Industrial_meat_production with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Industrialisation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/American_Society_for_Preventive_Cardiology with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Scientific_review with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Wholesaling with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Pedestrian with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Resource_depletion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Soil_erosion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sex_hormone with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Forced_abortion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Packaging_material with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Genetically_modified_organisms with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Otium with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Vestoj with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Net_metering with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Surf_culture with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Symbol with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_House_Day with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Trashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Recycled with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Outdoor_recreation with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/True_cost_accounting with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sustainable_Design with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Rudi_Gernreich with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Right_of_return with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Phase-out_of_fossil_fuel_vehicles with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Green_manure with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Skinny_jeans with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Fuyao_(fashion) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Juvenile_Protective_Association with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Strolling with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Adobe with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Style_(aesthetics) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Medical_devices with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/National_Heart,_Lung,_and_Blood_Institute with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Biofuel with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Buddhist_economics with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Kimono with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Rail_transport with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Internet_memes with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Self-expression_values with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Electric_blue_(colour) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Ancien_R%C3%A9gime with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Acute_(medicine) with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Overproduction with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Sportcoat with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Braless with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Human_physical_appearance with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/E-textiles with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Health_insurance with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/United_States_Department_of_Health_and_Human_Services with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Solar_combisystem with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Made_to_measure with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Meat_consumption with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/2000s_fashion with status code 403
# Failed to fetch the url: https://en.wikipedia.org/wiki/Jean_Baptiste_Say with status code 403
# Fetched: 474
# Failed: 424
#  ERROR : File data\wiki_raw_html.csv was not created
# Success! Data saved to: c:\Users\Violaine\OneDrive\Ecole\Master 1\Web mining\Projet Web Mining\Projet_Web_Mining\Extraction\data\wiki_raw_html.csv
# Raw HTML data saved to data\wiki_raw_html.csv
#
# === CREATE CSV OF NODES ===
# [wiki] Creating nodes CSV...
# Nodes CSV saved to data\wiki_nodes.csv
#
# === CREATE CSV OF EDGES ===
# [wiki] Creating edges CSV...
# Edges CSV saved to data\wiki_edges.csv

# %%
def filter_links(links, required_keywords=None, domain=None, already_seen=None):
    if required_keywords is None:  # If no list of required keywords is given then we create an empty one
        required_keywords = []
    if already_seen is None:  # If no list of already seen links is given then we create an empty one
        already_seen = set()
    
    filtered = []
    for l in links:
        l_lower = l.lower()  # Transformation of capital letter into lower case letter
        if required_keywords and not any(keyword.lower() in l_lower for keyword in required_keywords):  # The function skip the url if no required keywords are in the url
            continue
        if domain and urlparse(l).netloc != domain:  # The function filter the links that are not in the domain
            continue
        if l in already_seen:  # The function filter the links already in the list of links
            continue
        filtered.append(l) # If the url past all the filter, it is added to the list of links
    return filtered

# %%
{"name": "blogs",
     "start_url": "https://bloggers.feedspot.com/lifestyle_blogs/?fbclid=IwY2xjawPEh9BleHRuA2FlbQIxMQBzcnRjBmFwcF9pZAEwAAEeokJD-GCqzqIYQFsjgINZ-moY9eFBlfazeS-PqjVE0WpSysKa_blRr5IkTts_aem_iiBbwTznbHBpSm1tmO_7Eg",
     "crawler_func": crawl_feedspot_seed_links,
     "output_file": "data/blogs.csv"}

# %%
def extract_feedspot_seed_pages(url):
    
    soup = to_soup(url)
    links_blogs = set()

    if not soup:
        print(f"{RED}Error: Could not fetch main blogs page: {url}{RESET}")
        return set()

    blogs = soup.find_all('a', href=True) # and tag.get('class') and 'wb-ba' in tag.get('class') and any('ext' in c for c in tag.get('class')))

    for link in blogs:
        href = link.get('href') #if link.name == 'a' else link.text.strip()  if href and "http" in href and "bloggers.feedspot.com" not in href:
        
        if not href.startswith('https?'):
            href = urljoin(url, href)

        if urlparse(href).netloc != urlparse(url).netloc:
            if any(filter in href for filter in filters_noise):
                continue
            if "mindbodygreen.com" in href:
                 continue
            if href and "http" in href and "feedspot" not in href :
                links_blogs.add(href)
    
    return links_blogs

# %%
# === Exemple d'utilisation ===
url_test = "https://bloggers.feedspot.com/lifestyle_blogs/?fbclid=IwY2xjawPEh9BleHRuA2FlbQIxMQBzcnRjBmFwcF9pZAEwAAEeokJD-GCqzqIYQFsjgINZ-moY9eFBlfazeS-PqjVE0WpSysKa_blRr5IkTts_aem_iiBbwTznbHBpSm1tmO_7Eg"

crawl = extract_feedspot_seed_pages(url_test)
print(len(crawl))
print(crawl)
# Out:
# 99
# {'http://www.mrpogitips.com/', 'https://theperennialstyle.com/', 'https://flow-spirit.com/lifestyle-blogs/', 'https://onbetterliving.com/', 'https://julieblanner.com/', 'https://joylynnlifestyle.com/', 'https://an-ideal-life.com/category/an-ideal-life/', 'https://freshexchange.com/blog/', 'https://www.thirteenthoughts.com/', 'https://terilynadams.com/', 'https://www.zoella.co.uk/', 'https://helloadamsfamily.com/', 'https://www.mrglitterati.com/', 'https://witanddelight.com/', 'https://www.elizabethrider.com/', 'https://www.primermagazine.com/', 'https://cupofjo.com/', 'https://witwhimsy.com/', 'https://socialifestylemag.com/', 'https://freshlandmag.com/', 'https://lifestyleandberries.com/category/lifestyle/', 'https://jaceyoutwest.com/the-blog/', 'https://hollybeetells.com/', 'https://www.theskinnyconfidential.com/', 'https://treasuresandtravelsblog.com/blog/', 'https://goddesslikebody.com/', 'https://www.sazan.me/blog', 'https://livinginyellow.com/', 'https://www.ahealthysliceoflife.com/', 'https://ourbloglife.com/', 'https://www.dallaswardrobe.com/', 'https://simplytaralynn.com/', 'https://ivajorg.com/', 'https://theneguide.com/', 'https://sincerelyjules.com/', 'https://scoutthecity.com/', 'https://www.idyllicpursuit.com/', 'https://sweethumblehome.com/', 'https://meoneverything.blog/', 'https://crystalinmarie.com/', 'https://iamkelib.com/blog/', 'https://carlyriordan.com/', 'https://www.katiedidwhat.com/', 'https://heleneinbetween.com/blog/', 'https://www.apetogentleman.com/', 'https://abeautifulmess.com/', 'https://www.cluburb.com/', 'https://www.lizbreygel.com/', 'https://positivelypresent.com/archive', 'https://www.themarthablog.com/', 'https://hookonlook.com/category/life-style/', 'https://www.predupre.com/', 'https://richu1893.wordpress.com/', 'https://amelialiana.com/', 'https://goop.com/', 'https://blog.justinablakeney.com/', 'https://www.dailysweetness.com/', 'https://livingswag.com/', 'https://www.thepioneerwoman.com/', 'https://www.treastblog.com/', 'https://zerxza.com/', 'https://www.julesacree.com/all', 'https://www.artofmanliness.com/', 'https://alysonhaley.com/', 'https://50plano.com/', 'https://www.theblondeabroad.com/travel-blog/', 'https://www.beautycookskisses.com/', 'https://www.thesundaysnug.com/', 'https://happilyevaafter.com/', 'https://inspirationsandcelebrations.net/', 'https://www.beccatilleyblog.com/', 'https://www.pbfingers.com/', 'https://iamaileen.com/', 'https://thestripe.com/', 'https://lifestyleonabudget.com/category/tips-tricks/', 'https://www.ferbena.com/', 'https://hejdoll.com/', 'https://peplifestyle.com/luxury-lifestyle/', 'https://lifegram.org/', 'https://bushraslifestyle.com/blog/', 'https://www.consciouslifestylemag.com/', 'https://blueperkmoment.com/', 'https://theblueridgegal.com/', 'https://www.knowseeker.com/', 'https://www.sofiaclara.com/journal', 'https://camillestyles.com/', 'https://heleneinbetween.com/blog', 'https://pumpsandiron.com/', 'https://quintessenceblog.com/whats-new/', 'https://middleagedmama.com.au/', 'https://www.lifeoftrends.com/lifestyle', 'https://corporette.com/category/lifestyle/', 'https://loveandloathingla.com/', 'https://lmgfl.com/', 'https://www.superhitideas.com/', 'https://madeathomecrafts.com/', 'https://www.nearlyallthings.com/', 'https://meetat-thebarre.com/', 'https://dawnandhope.com/'}

# %%
# === Exemple d'utilisation ===
url_test = list(crawl)[:2]

for url in url_test:

    # Crawl en largeur
    breath_links, last_visited = extract_links_breadth_first(url, max_levels=1)
    print("Breath Links:", len(breath_links))
    print(breath_links)
    print("Last Level Links:", len(last_visited))
    print(last_visited)

    # Crawl en profondeur
    depth_links = extract_links_depth_from_list(
        start_links=last_visited, visited_links=breath_links.copy(),  # on copie pour ne pas modifier l'original
        max_depth=1, max_links_per_page=1)
    print("Depth Links:", len(depth_links))
    print(depth_links)
# Out:
# Breath Links: 117
# ['http://www.mrpogitips.com/', 'http://www.mrpogitips.com/feeds/comments/default', 'http://www.mrpogitips.com/feeds/posts/default', 'http://blogsngpinoy.com', 'http://feedjit.com/', 'http://ho.lazada.com.ph/shvukn', 'http://jasperroberts.com', 'http://mrpogitips.blogspot.com/p/blog-page.html', 'http://mrpogitips.blogspot.com/p/new-site.html', 'http://mrpogitips.blogspot.com/p/sample.html', 'http://www.addtoany.com/share_save', 'http://www.blogger.com', 'http://www.mrpogitips.com', 'http://www.mrpogitips.com/2013/', 'http://www.mrpogitips.com/2013/05/', 'http://www.mrpogitips.com/2013/06/', 'http://www.mrpogitips.com/2013/06/pigeon-powder-review.html', 'http://www.mrpogitips.com/2014/', 'http://www.mrpogitips.com/2014/07/', 'http://www.mrpogitips.com/2014/07/zen-zest-tea-tree-oil-review.html', 'http://www.mrpogitips.com/2014/10/', 'http://www.mrpogitips.com/2015/', 'http://www.mrpogitips.com/2015/03/', 'http://www.mrpogitips.com/2015/06/', 'http://www.mrpogitips.com/2015/07/', 'http://www.mrpogitips.com/2015/07/freshman-masculine-wash-review.html', 'http://www.mrpogitips.com/2015/08/', 'http://www.mrpogitips.com/2015/10/', 'http://www.mrpogitips.com/2015/11/', 'http://www.mrpogitips.com/2016/', 'http://www.mrpogitips.com/2016/04/', 'http://www.mrpogitips.com/2016/05/', 'http://www.mrpogitips.com/2016/05/queen-city-of