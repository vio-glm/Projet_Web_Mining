# %% [markdown]
# # **Link Analysis**

# %% [markdown]
# ## Imports statements

# %% [markdown]
# ##### If these packages are not already installed on your machine, please run: pip install networkx pandas numpy

# %%
import networkx as nx
import pandas as pd
import numpy as np
from collections import deque

# %% [markdown]
# ## Constants statements

# %%
# --- CONFIGURATION OF COLORS ---

GREEN = "\033[92m"
RED = "\033[91m"
BLUE = "\033[94m"
RESET = "\033[0m"

# %% [markdown]
# ## Fetching of csv files

# %% [markdown]
# ###### For Wikipedia

# %%
nodes_path = "data/wiki_nodes.csv"
edges_path = "data/wiki_edges.csv"

wiki_nodes = pd.read_csv(nodes_path)
wiki_edges = pd.read_csv(edges_path)

print(f"[Wiki] {len(wiki_nodes)} nodes")
print(f"[Wiki] {len(wiki_edges)} links")
# Out:
# [Wiki] 853 nodes
# [Wiki] 857 links

# %% [markdown]
# ###### For MindBodyGreen

# %%
nodes_path = "data/MBG_nodes.csv"
edges_path = "data/MBG_edges.csv"

MBG_nodes = pd.read_csv(nodes_path)
MBG_edges = pd.read_csv(edges_path)

print(f"[MBG] {len(MBG_nodes)} nodes")
print(f"[MBG] {len(MBG_edges)} edges")
# Out:
# [MBG] 1365 nodes
# [MBG] 10588 edges

# %% [markdown]
# ###### For Feedspot

# %%
nodes_path = "data/blogs_nodes.csv"
edges_path = "data/blogs_edges.csv"

blogs_nodes = pd.read_csv(nodes_path)
blogs_edges = pd.read_csv(edges_path)

print(f"[Blogs] {len(blogs_nodes)} nodes")
print(f"[Blogs] {len(blogs_edges)} edges")
# Out:
# [Blogs] 4050 nodes
# [Blogs] 19951 edges

# %% [markdown]
# ## Create Graphs

# %%
G_wiki = nx.from_pandas_edgelist(wiki_edges, source='source', target='target', create_using=nx.DiGraph())
G_MBG = nx.from_pandas_edgelist(MBG_edges, source='source', target='target', create_using=nx.DiGraph())
G_blogs = nx.from_pandas_edgelist(blogs_edges, source='source', target='target', create_using=nx.DiGraph())

# %%
def print_graph_stats(graph, name="Graphe"):
    
    n = graph.number_of_nodes()
    real_edges = graph.number_of_edges()
    
    if len(graph) > 0:
        largest_cc = max(nx.weakly_connected_components(graph), key=len)
        nodes_in_largest = len(largest_cc)
    else:
        nodes_in_largest = 0
            
    print(f"{BLUE}Graph Statistics:{RESET}")
    print(f"{BLUE}Total number of nodes: {n}{RESET}")
    print(f"{BLUE}Total number of direct edges: {real_edges}{RESET}")
    print(f"{BLUE}Graph density: {nx.density(graph):.6f}{RESET}")
    print(f"{BLUE}Nodes in the largest connected component: {nodes_in_largest} ({nodes_in_largest/n:.1%} of the total){RESET}")

# %%
print_graph_stats(G_wiki, "Wikipedia")
print_graph_stats(G_MBG, "MindBodyGreen")
print_graph_stats(G_blogs, "Blogs Feedspot")
# Out:
# Graph Statistics:
# Total number of nodes: 849
# Total number of direct edges: 857
# Graph density: 0.001190
# Nodes in the largest connected component: 849 (100.0% of the total)
# Graph Statistics:
# Total number of nodes: 1365
# Total number of direct edges: 5547
# Graph density: 0.002979
# Nodes in the largest connected component: 1365 (100.0% of the total)
# Graph Statistics:
# Total number of nodes: 4048
# Total number of direct edges: 11651
# Graph density: 0.000711
# Nodes in the largest connected component: 377 (9.3% of the total)

# %% [markdown]
# ## Degree Matrix

# %% [markdown]
# #### Implementation

# %%
def get_degree_stats(Graph):

    in_degrees = dict(Graph.in_degree()) # Optimised data retrieval from NetworkX
    out_degrees = dict(Graph.out_degree())
    
    df = pd.DataFrame({ # DataFrame creation
        'node_id': list(Graph.nodes()),
        'in_degree': [in_degrees.get(n, 0) for n in Graph.nodes()],
        'out_degree': [out_degrees.get(n, 0) for n in Graph.nodes()]})

    df.set_index('node_id', inplace=True) # We index the ID to facilitate searches
    
    print(f"\n{BLUE}Overview of calculated degrees: {RESET}")
    print(df.head()) # Display first rows

    active_in = len(df[df['in_degree'] > 0]) # Count active nodes (non-zero)
    print(f"\n{BLUE}Number of pages with at least 1 inbound link: {active_in}{RESET}")
    
    return df

# %% [markdown]
# #### Execution

# %%
wiki_degrees = get_degree_stats(G_wiki)
MBG_degrees = get_degree_stats(G_MBG)
blogs_degrees = get_degree_stats(G_blogs)
# Out:
# Overview of calculated degrees:
#                                                in_degree  out_degree
# node_id
# https://en.wikipedia.org/wiki/Lifestyle                0          47
# https://en.wikipedia.org/wiki/Milton_Rokeach           1           0
# https://en.wikipedia.org/wiki/Modernity                1           0
# https://en.wikipedia.org/wiki/German_language          1           0
# https://en.wikipedia.org/wiki/William_Dufty            1           0
#
# Number of pages with at least 1 inbound link: 845
#
# Overview of calculated degrees:
#                                                     in_degree  out_degree
# node_id
# https://www.mindbodygreen.com/                            168          33
# https://www.mindbodygreen.com/articles/anna-lei...          2          23
# https://www.mindbodygreen.com/articles/case-for...          1          25
# https://www.mindbodygreen.com/articles/fitness-...          1          26
# https://www.mindbodygreen.com/articles/heres-wh...          2          24
#
# Number of pages with at least 1 inbound link: 1365
#
# Overview of calculated degrees:
#                                                     in_degree  out_degree
# node_id
# https://40plusstyle.com/                                    8          32
# https://40plusstyle.com/arch-support-shoes/                 2          15
# https://40plusstyle.com/beauty-tips-for-women-o...          8          27
# https://40plusstyle.com/best-online-shops/                  8          15
# https://40plusstyle.com/category/fashion-tips-f...          8          27
#
# Number of pages with at least 1 inbound link: 4040

# %% [markdown]
# ## Degree centrality

# %% [markdown]
# #### Implementation

# %%
def degree_centrality(Graph):
    
    in_centrality = nx.in_degree_centrality(Graph) # We are particularly interested in In-Degree Centrality (Popularity)

    df = pd.DataFrame(list(in_centrality.items()), columns=['node_id', 'centrality_score'])
    df = df.sort_values('centrality_score', ascending=False) # Sort by descending score (stars first)
    
    print(df.head(10)) # Print only the 10 most central nodes

    return df

# %% [markdown]
# #### Execution

# %%
wiki_centrality = degree_centrality(G_wiki)
MBG_centrality = degree_centrality(G_MBG)
blogs_centrality = degree_centrality(G_blogs)
# Out:
#                                                node_id  centrality_score
# 216        https://en.wikipedia.org/wiki/United_States          0.002358
# 67     https://en.wikipedia.org/wiki/Physical_exercise          0.002358
# 399            https://en.wikipedia.org/wiki/Pollution          0.002358
# 37          https://en.wikipedia.org/wiki/Anthropology          0.002358
# 35          https://en.wikipedia.org/wiki/Georg_Simmel          0.002358
# 11   https://en.wikipedia.org/wiki/Sedentary_lifestyle          0.002358
# 46   https://en.wikipedia.org/wiki/Ecological_footp...          0.002358
# 47         https://en.wikipedia.org/wiki/Simple_living          0.002358
# 76   https://en.wikipedia.org/wiki/Lifestyle_(socio...          0.002358
# 300  https://en.wikipedia.org/wiki/Greenhouse_gas_e...          0.002358
#                                               node_id  centrality_score
# 0                      https://www.mindbodygreen.com/          0.123167
# 29  https://institute.mindbodygreen.com/functional...          0.119501
# 30  https://institute.mindbodygreen.com/health-coa...          0.119501
# 31  https://institute.mindbodygreen.com/peri-menop...          0.119501
# 16               https://www.mindbodygreen.com/beauty          0.117302
# 18               https://www.mindbodygreen.com/health          0.117302
# 17                 https://www.mindbodygreen.com/food          0.117302
# 21          https://www.mindbodygreen.com/mindfulness          0.117302
# 22             https://www.mindbodygreen.com/movement          0.117302
# 24               https://www.mindbodygreen.com/planet          0.117302
#                                 node_id  centrality_score
# 1367            https://cultivatewp.com          0.004448
# 1709  https://podcasts.apple.com/ai/new          0.003212
# 1711  https://podcasts.apple.com/am/new          0.003212
# 1712  https://podcasts.apple.com/ao/new          0.003212
# 1713  https://podcasts.apple.com/ar/new          0.003212
# 1714  https://podcasts.apple.com/at/new          0.003212
# 1706  https://podcasts.apple.com/ae/new          0.003212
# 1707  https://podcasts.apple.com/af/new          0.003212
# 1708  https://podcasts.apple.com/ag/new          0.003212
# 1716  https://podcasts.apple.com/az/new          0.003212

# %% [markdown]
# ###### For Wikipedia

# %% [markdown]
# ## Shortest Path

# %% [markdown]
# #### Configuration

# %%
start_node_wiki = 'https://en.wikipedia.org/wiki/Lifestyle'
end_node_wiki = 'https://en.wikipedia.org/wiki/Healthy_lifestyle'

start_node_MBG = 'https://www.mindbodygreen.com/movement'
end_node_MBG = 'https://www.mindbodygreen.com/articles/health-coach-vs-life-coach'

start_node_blogs = 'https://40plusstyle.com/beauty-tips-for-women-over-40/'
end_node_blogs = 'https://40plusstyle.com/best-online-shops/'

# %% [markdown]
# #### Implementation

# %%
def shortest_path(G, start_node, end_node):
    
    # Checking for the presence of nodes
    if start_node not in G:
        print(f"{RED}Error: The start page does not exist in your data{RESET}")
        print(f"{GREEN}URL searched: {start_node}{RESET}")
        return None
    
    if end_node not in G:
        print(f"{RED}Error: The end page does not exist in your data{RESET}")
        print(f"{GREEN}URL searched: {end_node}{RESET}")
        return None
    
    # Shortest path calculation
    try:
        path = nx.shortest_path(G, source=start_node, target=end_node)
        print(f"{GREEN}Path found! Distance: {len(path)-1} click(s){RESET}\n")

        for i, page in enumerate(path):
            
            if i == 0:
                print(f"{BLUE}START: {page}{RESET}\n")
            
            elif i == len(path) - 1:
                print(f"{BLUE}ARRIVAL: {page}{RESET}\n")
            
            else:
                print(f"{BLUE}Step {i}: {page}{RESET}\n")

        return path
        
    except nx.NetworkXNoPath:
        print(f"{RED}No path found between these two pages in your data{RESET}")
        return None

# %%
def shortest_path_matrix(A: np.ndarray) -> np.ndarray:
    n = A.shape[0]  # Number of nodes = size of A
    SP_matrix = np.full((n, n), np.inf)  # We initalize the distance matrix with the same size as A and with an infinite value everywhere
    
    for start in range(n):
        visited = [False] * n
        queue = deque()   
        queue.append(start)
        visited[start] = True
        SP_matrix[start, start] = 0  # The distance A -> A is null
        
        while queue:
            current = queue.popleft()           
            neighbors = np.where(A[current] > 0)[0]

            for neighbor in neighbors:
                if not visited[neighbor]:
                    visited[neighbor] = True
                    SP_matrix[start, neighbor] = SP_matrix[start, current] + 1 
                    queue.append(neighbor)
    
    return SP_matrix

# %%
def shortest_path_matrix_from_graph(G):
    # Convertit le graphe en matrice d'adjacence numpy
    A = nx.to_numpy_array(G, dtype=int)
    nodes = list(G.nodes())
    
    # Appelle ta fonction existante
    SP = shortest_path_matrix(A)
    
    return SP, nodes

# %% [markdown]
# #### Execution

# %%
path_wiki = shortest_path(G_wiki, start_node_wiki, end_node_wiki)
path_MBG = shortest_path(G_MBG, start_node_MBG, end_node_MBG)
path_blogs = shortest_path(G_blogs, start_node_blogs, end_node_blogs)
# Out:
# Path found! Distance: 1 click(s)
#
# START: https://en.wikipedia.org/wiki/Lifestyle
#
# ARRIVAL: https://en.wikipedia.org/wiki/Healthy_lifestyle
#
# Path found! Distance: 3 click(s)
#
# START: https://www.mindbodygreen.com/movement
#
# Step 1: https://www.mindbodygreen.com/
#
# Step 2: https://institute.mindbodygreen.com/
#
# ARRIVAL: https://www.mindbodygreen.com/articles/health-coach-vs-life-coach
#
# Path found! Distance: 2 click(s)
#
# START: https://40plusstyle.com/beauty-tips-for-women-over-40/
#
# Step 1: https://40plusstyle.com/
#
# ARRIVAL: https://40plusstyle.com/best-online-shops/

# %%
SP_wiki, nodes_wiki = shortest_path_matrix_from_graph(G_wiki)
SP_MBG, nodes_MBG = shortest_path_matrix_from_graph(G_MBG)
SP_blogs, nodes_blogs = shortest_path_matrix_from_graph(G_blogs)

print(f"\n{BLUE} Computation of shortest path matrix for Wikipedia {RESET}")
print(SP_wiki)

print(f"\n{BLUE} Computation of shortest path matrix for MindBodyGreen {RESET}")
print(SP_MBG)

print(f"\n{BLUE} Computation of shortest path matrix for Feedspot {RESET}")
print(SP_blogs)
# Out:
#  Computation of shortest path matrix for Wikipedia
# [[ 0.  1.  1. ... inf inf inf]
#  [inf  0. inf ... inf inf inf]
#  [inf inf  0. ... inf inf inf]
#  ...
#  [inf inf inf ...  0. inf inf]
#  [inf inf inf ... inf  0. inf]
#  [inf inf inf ... inf inf  0.]]
#
#  Computation of shortest path matrix for MindBodyGreen
# [[ 0.  1.  1. ...  3.  3.  3.]
#  [ 1.  0.  2. ...  3.  3.  3.]
#  [ 1.  2.  0. ...  3.  3.  3.]
#  ...
#  [inf inf inf ...  0. inf inf]
#  [inf inf inf ... inf  0. inf]
#  [inf inf inf ... inf inf  0.]]
#
#  Computation of shortest path matrix for Feedspot
# [[ 0.  1.  1. ... inf inf inf]
#  [inf  0. inf ... inf inf inf]
#  [ 1.  2.  0. ... inf inf inf]
#  ...
#  [inf inf inf ...  0. inf inf]
#  [inf inf inf ... inf  0. inf]
#  [inf inf inf ... inf inf  0.]]

# %% [markdown]
# ## Betweenness centrality

# %% [markdown]
# #### Implementation

# %%
def get_betweenness(Graph): # Calculates Betweenness Centrality (with optimisation k=100 if necessary)
    
    # If the graph is large (>2000 nodes), we approximate to save time.
    if len(Graph) > 2000:
        scores = nx.betweenness_centrality(Graph, k=100)
    else:
        scores = nx.betweenness_centrality(Graph)
        
    df = pd.DataFrame(list(scores.items()), columns=['node_id', 'Betweenness'])

    return df.sort_values('Betweenness', ascending=False)

# %% [markdown]
# #### Execution

# %%
print(f"\n{BLUE}--- Betweenness calculations ---{RESET}")

wiki_betweenness = get_betweenness(G_wiki)
MBG_betweenness = get_betweenness(G_MBG)
blogs_betweenness = get_betweenness(G_blogs)

print(f"\n{GREEN}Top 5 Wikipedia:{RESET}")
print(wiki_betweenness.head(5))

print(f"\n{GREEN}Top 5 MBG:{RESET}")
print(MBG_betweenness.head(5))

print(f"\n{GREEN}Top 5 Blogs:{RESET}")
print(blogs_betweenness.head(5))
# Out:
# --- Betweenness calculations ---
#
# Top 5 Wikipedia:
#                                               node_id  Betweenness
# 26   https://en.wikipedia.org/wiki/Sustainable_living       0.0004
# 833      https://en.wikipedia.org/wiki/Rudi_Gernreich       0.0000
# 817     https://en.wikipedia.org/wiki/Market_research       0.0000
# 2             https://en.wikipedia.org/wiki/Modernity       0.0000
# 3       https://en.wikipedia.org/wiki/German_language       0.0000
#
# Top 5 MBG:
#                                               node_id  Betweenness
# 0                      https://www.mindbodygreen.com/     0.067526
# 33  https://podcasts.apple.com/us/podcast/the-mind...     0.010389
# 19   https://www.mindbodygreen.com/integrative-health     0.006446
# 10  https://www.mindbodygreen.com/articles/peter-a...     0.006431
# 17                 https://www.mindbodygreen.com/food     0.005832
#
# Top 5 Blogs:
#                                                 node_id  Betweenness
# 2387                        https://sunnysweetdays.com/     0.000198
# 429                         https://bestofthislife.com/     0.000175
# 2394  https://sunnysweetdays.com/the-secret-to-hosti...     0.000115
# 966                         https://freshmommyblog.com/     0.000067
# 3947                    https://www.wisconsinmommy.com/     0.000059

# %% [markdown]
# ## Page Rank

# %% [markdown]
# #### Implementation

# %%
def get_pagerank(Graph, name="Graphe"):

    print(f"{BLUE}Calculation of advanced metrics for: {name}...{RESET}\n")

    pr = nx.pagerank(Graph, alpha=0.85) # Calcules PageRank with damping factor 0.85
    
    reverse_pr = nx.pagerank(Graph.reverse(), alpha=0.85)

    df = pd.DataFrame({
        'node_id': list(Graph.nodes()),
        'pagerank_score': [pr.get(n, 0) for n in Graph.nodes()],
        'reverse_pagerank_score': [reverse_pr.get(n, 0) for n in Graph.nodes()]
    })
    
    return df.sort_values('pagerank_score', ascending=False)

# %%
def get_personalized_pagerank(Graph, name="Graphe", keyword="lifestyle"):
    print(f"Computation of PageRank for: {name}")

    # We search for pages that contain the keyword.
    personalization = {}
    found_count = 0

    for node in Graph.nodes():

        if keyword in str(node).lower():
            personalization[node] = 100.0 # Big bonus
            found_count += 1
        else:
            personalization[node] = 1.0  # Normal weight
    
    if found_count == 0:
        print(f"{RED}No page found with the keyword '{keyword}'.{RESET}")
        return pd.DataFrame()
    else:
        print(f"{BLUE}Pages found with the keyword '{keyword}': {found_count}{RESET}")

    # Calculation of biased PageRank
    # If no page has the keyword, we perform a normal PageRank calculation
    try:
        total_weight = sum(personalization.values())
        personalization = {k: v/total_weight for k, v in personalization.items()}
        
        ppr_scores = nx.pagerank(Graph, alpha=0.85, personalization=personalization)
        
        df = pd.DataFrame(list(ppr_scores.items()), columns=['node_id', 'Personalized_PR'])
        return df.sort_values('Personalized_PR', ascending=False)
        
    except Exception as e:
        print(f"{RED}Error: {e}{RESET}")
        return pd.DataFrame()

# %% [markdown]
# #### Execution

# %%
print(f"\n{BLUE}--- Calculate PageRank (Normal and Reverse) ---{RESET}")

wiki_pagerank = get_pagerank(G_wiki, "Wikipedia")
MBG_pagerank = get_pagerank(G_MBG, "MindBodyGreen")
blogs_pagerank = get_pagerank(G_blogs, "Blogs Feedspot")

print(f"\n{GREEN}Top 5 Wikipedia:{RESET}")
print(wiki_pagerank.head(5))

print(f"\n{GREEN}Top 5 MBG:{RESET}")
print(MBG_pagerank.head(5))

print(f"\n{GREEN}Top 5 Blogs:{RESET}")
print(blogs_pagerank.head(5))
# Out:
# --- Calculate PageRank (Normal and Reverse) ---
# Calculation of advanced metrics for: Wikipedia...
#
# Calculation of advanced metrics for: MindBodyGreen...
#
# Calculation of advanced metrics for: Blogs Feedspot...
#
#
# Top 5 Wikipedia:
#                                               node_id  pagerank_score  \
# 11  https://en.wikipedia.org/wiki/Sedentary_lifestyle        0.001212
# 16      https://en.wikipedia.org/wiki/Pierre_Bourdieu        0.001197
# 37         https://en.wikipedia.org/wiki/Anthropology        0.001197
# 35         https://en.wikipedia.org/wiki/Georg_Simmel        0.001197
# 46  https://en.wikipedia.org/wiki/Ecological_footp...        0.001197
#
#     reverse_pagerank_score
# 11                0.000564
# 16                0.000564
# 37                0.000564
# 35                0.000564
# 46                0.000564
#
# Top 5 MBG:
#                                               node_id  pagerank_score  \
# 0                      https://www.mindbodygreen.com/        0.010217
# 30  https://institute.mindbodygreen.com/health-coa...        0.007354
# 29  https://institute.mindbodygreen.com/functional...        0.007279
# 31  https://institute.mindbodygreen.com/peri-menop...        0.007279
# 17                 https://www.mindbodygreen.com/food        0.006274
#
#     reverse_pagerank_score
# 0                 0.147984
# 30                0.003178
# 29                0.002899
# 31                0.002899
# 17                0.015300
#
# Top 5 Blogs:
#                                                 node_id  pagerank_score  \
# 3616           https://www.theskimm.com/partner-content        0.000478
# 3615                   https://www.theskimm.com/careers        0.000478
# 3272  https://www.itscarmen.com/2025/09/harbour-gall...        0.000449
# 924   https://cupofjo.com/2025/12/04/gift-guide-9-no...        0.000442
# 3203  https://www.honeywerehome.com/fashion/fall-winter        0.000442
#
#       reverse_pagerank_score
# 3616                0.000040
# 3615                0.000040
# 3272                0.001551
# 924                 0.002131
# 3203                0.002131

# %%
print(f"{BLUE}--- Focus : Lifestyle ---{RESET}")

KEYWORD = "lifestyle" # We can change it easily to ‘health’, ‘food’, etc.
print(f"{BLUE}--- Custom PageRank (Keyword: '{KEYWORD}') ---{RESET}")

wiki_perso = get_personalized_pagerank(G_wiki, "Wikipedia", keyword=KEYWORD)
if not wiki_perso.empty:
    print(f"\n{GREEN}Top 5 Wiki (Focus {KEYWORD}) :{RESET}")
    print(wiki_perso.head(5))

MBG_perso = get_personalized_pagerank(G_MBG, "MBG", keyword=KEYWORD)
if not MBG_perso.empty:
    print(f"\n{GREEN}Top 5 MBG (From a lifestyle perspective):{RESET}")
    print(MBG_perso.head(5))

blogs_perso = get_personalized_pagerank(G_blogs, "Blogs", keyword=KEYWORD)
if not blogs_perso.empty:
    print(f"\n{GREEN}Top 5 Blogs (Focus {KEYWORD}) :{RESET}")
    print(blogs_perso.head(5))
# Out:
# --- Focus : Lifestyle ---
# --- Custom PageRank (Keyword: 'lifestyle') ---
# Computation of PageRank for: Wikipedia
# Pages found with the keyword 'lifestyle': 10
#
# Top 5 Wiki (Focus lifestyle) :
#                                               node_id  Personalized_PR
# 11  https://en.wikipedia.org/wiki/Sedentary_lifestyle         0.052788
# 32      https://en.wikipedia.org/wiki/Green_lifestyle         0.052780
# 10      https://en.wikipedia.org/wiki/Lifestyle_brand         0.052780
# 31   https://en.wikipedia.org/wiki/Lifestyle_medicine         0.052780
# 28    https://en.wikipedia.org/wiki/Healthy_lifestyle         0.052780
# Computation of PageRank for: MBG
# Pages found with the keyword 'lifestyle': 3
#
# Top 5 MBG (From a lifestyle perspective):
#                                                 node_id  Personalized_PR
# 20              https://www.mindbodygreen.com/lifestyle         0.048551
# 1016  https://www.mindbodygreen.com/articles/new-res...         0.040244
# 470   https://www.mindbodygreen.com/articles/avoid-s...         0.040232
# 0                        https://www.mindbodygreen.com/         0.017919
# 30    https://institute.mindbodygreen.com/health-coa...         0.010040
# Computation of PageRank for: Blogs
# Pages found with the keyword 'lifestyle': 39
#
# Top 5 Blogs (Focus lifestyle) :
#                                                 node_id  Personalized_PR
# 3948  http://www.wisconsinmommy.com/maureen-fitzgera...         0.012314
# 3953  https://www.wisconsinmommy.com/maureen-fitzger...         0.012015
# 3192        https://www.caviarandcashmere.com/lifestyle         0.011911
# 2309     https://sincerelyjules.com/category/lifestyle/         0.011895
# 3639   https://www.theskinnyconfidential.com/lifestyle/         0.011888

# %% [markdown]
# ## HITS

# %% [markdown]
# #### Implementation

# %%
def get_hits(Graph):
    # Calculates Hub and Authority scores
    try:
        hubs, authorities = nx.hits(Graph, max_iter=100, tol=1e-08)
        
        df = pd.DataFrame({
            'node_id': list(Graph.nodes()),
            'Hub_Score': [hubs.get(n, 0) for n in Graph.nodes()],
            'Authority_Score': [authorities.get(n, 0) for n in Graph.nodes()]
        })
        # Returns sorted by Authority by default
        return df.sort_values('Authority_Score', ascending=False)
        
    except Exception as e:
        print(f"{RED}HITS error (non-convergence): {e}{RESET}")

        return pd.DataFrame()

# %% [markdown]
# #### Execution

# %%
print(f"\n{BLUE}--- HITS calculations ---{RESET}")

wiki_hits = get_hits(G_wiki)
MBG_hits = get_hits(G_MBG)
blogs_hits = get_hits(G_blogs)

print(f"\n{GREEN}Top 5 Wikipedia (Authorities) :{RESET}")
print(wiki_hits[['node_id', 'Authority_Score']].head(5))

print(f"\n{GREEN}Top 5 MBG (Authorities) :{RESET}")
print(MBG_hits[['node_id', 'Authority_Score']].head(5))

print(f"\n{GREEN}Top 5 Blogs (Authorities) :{RESET}")
print(blogs_hits[['node_id', 'Authority_Score']].head(5))
# Out:
# --- HITS calculations ---
#
# Top 5 Wikipedia (Authorities) :
#                                                node_id  Authority_Score
# 472               https://en.wikipedia.org/wiki/London         0.003460
# 399            https://en.wikipedia.org/wiki/Pollution         0.003460
# 300  https://en.wikipedia.org/wiki/Greenhouse_gas_e...         0.003460
# 46   https://en.wikipedia.org/wiki/Ecological_footp...         0.002864
# 47         https://en.wikipedia.org/wiki/Simple_living         0.002864
#
# Top 5 MBG (Authorities) :
#                                     node_id  Authority_Score
# 18     https://www.mindbodygreen.com/health         0.042218
# 17       https://www.mindbodygreen.com/food         0.042218
# 20  https://www.mindbodygreen.com/lifestyle         0.042218
# 16     https://www.mindbodygreen.com/beauty         0.042218
# 24     https://www.mindbodygreen.com/planet         0.042218
#
# Top 5 Blogs (Authorities) :
#                                        node_id  Authority_Score
# 1077          https://hisugarplum.com/2011/01/         0.003695
# 1078          https://hisugarplum.com/2011/02/         0.003695
# 1277  https://hisugarplum.com/category/beauty/         0.003695
# 1262          https://hisugarplum.com/2025/04/         0.003695
# 1263          https://hisugarplum.com/2025/05/         0.003695

# %% [markdown]
# ## Merge

# %% [markdown]
# #### Implementation

# %%
def merge_metrics(pagerank_df, betweenness_df, hits_df): # Merges the DataFrames of the metrics into a single one

    df = pagerank_df.copy()
    
    if 'Betweenness' in betweenness_df.columns:
        df = df.join(betweenness_df[['Betweenness']], how='outer')
        
    if 'Authority_Score' in hits_df.columns:
        df = df.join(hits_df[['Authority_Score', 'Hub_Score']], how='outer')
        
    return df

# %% [markdown]
# #### Execution

# %%
print(f"\n{BLUE}--- Metrics fusion ---{RESET}")

wiki_metrics = merge_metrics(wiki_pagerank, wiki_betweenness, wiki_hits)
MBG_metrics = merge_metrics(MBG_pagerank, MBG_betweenness, MBG_hits)
blogs_metrics = merge_metrics(blogs_pagerank, blogs_betweenness, blogs_hits)

print(f"{GREEN}Metrics merge successful !{RESET}")
print(wiki_metrics.head())
# Out:
# --- Metrics fusion ---
# Metrics merge successful !
#                                                     pagerank_score  \
# node_id
# https://en.wikipedia.org/wiki/1300%E2%80%931400...        0.001176
# https://en.wikipedia.org/wiki/16th_century                0.001176
# https://en.wikipedia.org/wiki/1970s_fashion               0.001176
# https://en.wikipedia.org/wiki/2000s_fashion               0.001176
# https://en.wikipedia.org/wiki/2016_United_State...        0.001176
#
#                                                     reverse_pagerank_score  \
# node_id
# https://en.wikipedia.org/wiki/1300%E2%80%931400...                0.000564
# https://en.wikipedia.org/wiki/16th_century                        0.000564
# https://en.wikipedia.org/wiki/1970s_fashion                       0.000564
# https://en.wikipedia.org/wiki/2000s_fashion                       0.000564
# https://en.wikipedia.org/wiki/2016_United_State...                0.000564
#
#                                                     Betweenness  \
# node_id
# https://en.wikipedia.org/wiki/1300%E2%80%931400...          0.0
# https://en.wikipedia.org/wiki/16th_century                  0.0
# https://en.wikipedia.org/wiki/1970s_fashion                 0.0
# https://en.wikipedia.org/wiki/2000s_fashion                 0.0
# https://en.wikipedia.org/wiki/2016_United_State...          0.0
#
#                                                     Authority_Score  Hub_Score
# node_id
# https://en.wikipedia.org/wiki/1300%E2%80%931400...         0.000627        0.0
# https://en.wikipedia.org/wiki/16th_century                 0.000627        0.0
# https://en.wikipedia.org/wiki/1970s_fashion                0.000627        0.0
# https://en.wikipedia.org/wiki/2000s_fashion                0.000627        0.0
# https://en.wikipedia.org/wiki/2016_United_State...         0.000627        0.0

# %% [markdown]
# ## Analysis of inter- and intra- theme

# %% [markdown]
# #### Implementation

# %%
def analyze_themes(Graph, nodes_df, metrics_df, name, theme_col='topic'):
    # Analyzes homophily (links between similar themes) and theme‑level scores

    print(f"\n=== THEMATIC ANALYSIS: {name.upper()} ==={RESET}")

    if theme_col not in nodes_df.columns:  # Checking the theme column
        print(f"\n{RED}Column {theme_col} not found in nodes.csv for {name}{RESET}")
        print(f"\n{GREEN}Available columns: {list(nodes_df.columns)}{RESET}")
        return

    # Preparation: URL → Theme mapping
    id_col = 'node_id'
    url_to_theme = dict(zip(nodes_df[id_col], nodes_df[theme_col]))

    # Add the theme attribute to the graph
    nx.set_node_attributes(Graph, url_to_theme, name='theme')

    # Homophily calculation
    intra, inter, unknown = 0, 0, 0
    
    for u, v in Graph.edges():
        t_u = Graph.nodes[u].get('theme', 'Unknown')
        t_v = Graph.nodes[v].get('theme', 'Unknown')
        
        if t_u == 'Unknown' or t_v == 'Unknown' or pd.isna(t_u) or pd.isna(t_v):
            unknown += 1

        elif t_u == t_v:
            intra += 1

        else:
            inter += 1
            
    valid = intra + inter
    
    if valid > 0:
        print("Homophily (Tendency to cite within the same theme):")
        print(f"Intra-theme links: {intra} ({intra/valid:.1%})")
        print(f"Inter-theme links: {inter} ({inter/valid:.1%})")
    else:
        print("Not enough qualified links to compute homophily.")

    # Theme-level scores (merged with previously computed metrics)
    if metrics_df is not None and not metrics_df.empty:
        analysis = metrics_df.copy()
        analysis['theme'] = analysis.index.map(url_to_theme)
        
        # Keep only numerical columns for averaging
        cols_to_mean = ['pagerank_score', 'Betweenness', 'Authority']
        cols_existing = [c for c in cols_to_mean if c in analysis.columns]
        
        if cols_existing:
            stats = analysis.groupby('theme')[cols_existing].mean()
            print("\nAverage Influence by Theme (Top 3 PageRank):")
            print(stats.sort_values('pagerank_score', ascending=False).head(3))
            
            # Bridges (Top 5% Betweenness)
            if 'Betweenness' in analysis.columns:
                thresh = analysis['Betweenness'].quantile(0.95)
                bridges = analysis[analysis['Betweenness'] >= thresh]
                print("\nBridges (Top 5% Betweenness):")
                print(bridges[['Betweenness']].head(5))

# %% [markdown]
# #### Execution

# %%
nodes_path_topics = "data/blogs_nodes_topics.csv"

blogs_nodes_topics = pd.read_csv(nodes_path_topics)

# %%
try:
    analyze_themes(G_blogs, blogs_nodes_topics, blogs_metrics, "Blogs", theme_col='topic')

except Exception as e:
    print(f"{RED}Error during the loading or analysis: {e}{RESET}")
# Out:
# === THEMATIC ANALYSIS: BLOGS ===
# Homophily (Tendency to cite within the same theme):
# Intra-theme links: 2674 (69.0%)
# Inter-theme links: 1203 (31.0%)
#
# Average Influence by Theme (Top 3 PageRank):
#        pagerank_score   Betweenness
# theme
# 0.0          0.000255  1.882733e-06
# 8.0          0.000251  0.000000e+00
# 1.0          0.000250  1.385441e-07
#
# Bridges (Top 5% Betweenness):
#                                      Betweenness
# node_id
# http://24diner.com/                          0.0
# http://abeautifulmess.com/                   0.0
# http://accessprivacy.hearstmags.com          0.0
# http://alexagmarsh.blogspot.com/             0.0
# http://amzn.to/1l0gzq0                       0.0

# %%
# Verify if the fact that the Betweenness is nul for all topic is normal
nx.betweenness_centrality(G_blogs)
# Out:
# {'https://40plusstyle.com/': 6.140772272803946e-06,
#  'https://40plusstyle.com/arch-support-shoes/': 8.244696736236028e-06,
#  'https://40plusstyle.com/beauty-tips-for-women-over-40/': 7.550004696423548e-06,
#  'https://40plusstyle.com/best-online-shops/': 8.244696736236028e-06,
#  'https://40plusstyle.com/category/fashion-tips-for-women-over-40/': 6.516145899339982e-06,
#  'https://40plusstyle.com/category/how-to-dress-after-40/': 4.141978598442385e-06,
#  'https://40plusstyle.com/category/how-to-dress-after-40/how-to-accessorize/': 7.39710701356372e-06,
#  'https://40plusstyle.com/category/how-to-dress-after-40/how-to-create-a-wardrobe-your-love/': 7.736055657164534e-06,
#  'https://40plusstyle.com/category/how-to-dress-after-40/how-to-dress-for-your-body-type/': 7.186409208082132e-06,
#  'https://40plusstyle.com/category/how-to-dress-after-40/what-shoes-to-wear-after-40/': 1.1430901231551793e-05,
#  'https://40plusstyle.com/category/how-to-dress-after-40/what-to-wear/': 6.148188137593151e-06,
#  'https://40plusstyle.com/category/how-to-dress-for-your-body-type/': 0.0,
#  'https://40plusstyle.com/category/style-inspiration-tips-for-women-over-40/': 0.0,
#  'https://40plusstyle.com/christmas-party-looks/': 0.0,
#  'https://40plusstyle.com/disclosure/': 0.0,
#  'https://40plusstyle.com/faux-fur-outfits/': 0.0,
#  'https://40plusstyle.com/free-guide-10-steps-to-finding-your-style/': 0.0,
#  'https://40plusstyle.com/fun-style-personality-quiz-to-find-out-your-dominant-and-secondary-style/': 0.0,
#  'https://40plusstyle.com/how-to-dress-a-pear-shaped-body/': 0.0,
#  'https://40plusstyle.com/how-to-dress-after-forty/': 0.0,
#  'https://40plusstyle.com/how-to-dress-the-apple-body-shape/': 0.0,
#  'https://40plusstyle.com/fall-womens-sneakers/': 0.0,
#  'https://40plusstyle.com/most-comfortable-heels/': 0.0,
#  'https://40plusstyle.com/shoes-for-flat-feet/': 0.0,
#  'https://40plusstyle.com/shoes-to-wear-with-dresses/': 0.0,
#  'https://40plusstyle.com/stylish-summer-shoes/': 0.0,
#  'https://40plusstyle.com/the-best-shoes-for-winter-that-arent-boots/': 0.0,
#  'https://40plusstyle.com/waterproof-boots-for-women-that-look-chic-in-any-downpour/': 0.0,
#  'https://40plusstyle.com/what-shoes-to-wear-with-different-styles-of-pants/': 0.0,
#  'https://40plusstyle.com/bathing-suits-for-women-over-40/': 0.0,
#  'https://40plusstyle.com/category/how-to-dress-after-40/what-to-wear/page/2/': 0.0,
#  'https://40plusstyle.com/fashionable-travel-clothes/': 0.0,
#  'https://40plusstyle.com/maritime-style/': 0.0,
#  'https://40plusstyle.com/spring-layering/': 0.0,
#  'https://40plusstyle.com/summer-events-outfits/': 0.0,
#  'https://40plusstyle.com/traveling-light/': 0.0,
#  'https://40plusstyle.com/weekend-outfits-for-fall/': 0.0,
#  'https://40plusstyle.com/what-to-wear-in-hot-weather/': 0.0,
#  'https://9to5chic.com/': 0.0,
#  'https://9to5chic.com/2026/01/happy-new-year-5.html': 3.4607369016299367e-07,
#  'https://9to5chic.com/category/fallwinter': 3.643952384657405e-06,
#  'https://9to5chic.com/category/look-for-less': 3.1553777632508245e-06,
#  'https://9to5chic.com': 0.0,
#  'https://9to5chic.com/2019/03/suited-up-3.html': 0.0,
#  'https://9to5chic.com/2019/09/olive-20.html': 0.0,
#  'https://9to5chic.com/2020/09/a-rare-sale.html': 0.0,
#  'https://9to5chic.com/category/beauty': 0.0,
#  'https://9to5chic.com/category/blazer': 0.0,
#  'https://9to5chic.com/category/budget': 0.0,
#  'https://9to5chic.com/category/dresses': 0.0,
#  'https://9to5chic.com/category/fitness': 0.0,
#  'https://9to5chic.com/category/flats': 0.0,
#  'https://9to5chic.com/category/holiday-gift-guide': 0.0,
#  'https://9to5chic.com/category/home': 0.0,
#  'https://9to5chic.com/category/inspiration': 0.0,
#  'https://9to5chic.com/category/jeans': 0.0,
#  'https://9to5chic.com/category/jewelry': 0.0,
#  'https://9to5chic.com/2023/12/christmas-eve.html': 0.0,
#  'https://9to5chic.com/2023/12/jumpsuit-4.html': 0.0,
#  'https://9to5chic.com/2023/12/last-minute-4.html': 0.0,
#  'https://9to5chic.com/2023/12/navy-21.html': 0.0,
#  'https://9to5chic.com/2023/12/olive-29.html': 0.0,
#  'https://9to5chic.com/2023/12/tweed-14.html': 0.0,
#  'https://9to5chic.com/2024/01/gray-18.html': 0.0,
#  'https://9to5chic.com/2024/01/happy-new-year-4.html': 0.0,
#  'https://9to5chic.com/2024/01/jacket-jeans.html': 0.0,
#  'https://9to5chic.com/2024/01/winter-white-4.html': 0.0,
#  'https://9to5chic.com/category/fallwinter/': 0.0,
#  'https://9to5chic.com/category/lately': 0.0,
#  'https://awellstyledlife.com/category/beauty/makeup/': 0.0,
#  'https://awellstyledlife.com/category/beauty/skin-care/': 0.0,
#  'https://awellstyledlife.com/category/fashion/': 0.0,
#  'https://awellstyledlife.com/category/fashion/dressing-room-try-on/': 0.0,
#  'https://awellstyledlife.com/category/fashion/spring-fashion/': 0.0,
#  'https://awellstyledlife.com/category/fashion/style-tips/': 0.0,
#  'https://awellstyledlife.com/category/fashion/summer-fashion/': 0.0,
#  'https://awellstyledlife.com/category/fashion/winter-fashion/': 0.0,
#  'https://awellstyledlife.com/category/travel/': 0.0,
#  'https://awellstyledlife.com/aging-naturally-and-the-fear-of-looking-older/comment-page-2/': 0.0,
#  'https://awellstyledlife.com/category/travel/cruising/': 0.0,
#  'https://awellstyledlife.com/category/travel/packing/': 0.0,
#  'https://awellstyledlife.com/category/wellness/': 0.0,
#  'https://awellstyledlife.com/meet-jennifer-connolly/': 0.0,
#  'https://awellstyledlife.com/weekend-reading-12-06-25/': 0.0,
#  'https://awellstyledlife.com/where-i-shop/': 0.0,
#  'https://awellstyledlife.com/work-with-a-well-styled-life/': 0.0,
#  'https://awellstyledlife.myflodesk.com/signup': 0.0,
#  'https://go.shopmy.us/p-27464294': 0.0,
#  'https://go.shopmy.us/p-34367168': 0.0,
#  'https://go.shopmy.us/p-34368583': 0.0,
#  'https://go.shopmy.us/p-34635957': 0.0,
#  'https://go.shopmy.us/p-34637542': 0.0,
#  'https://go.shopmy.us/p-34707681': 0.0,
#  'https://amzlink.to/az039vxhb4bcl': 0.0,
#  'https://amzlink.to/az0jlomfycdcw': 0.0,
#  'https://awellstyledlife.com/best-fall-lip-colors-for-mature-skin/comment-page-2/': 0.0,
#  'https://awellstyledlife.com/best-foundation-for-mature-skin-women-over-60/': 0.0,
#  'https://awellstyledlife.com/best-mineral-sunscreens-for-mature-skin/': 0.0,
#  'https://awellstyledlife.com/favorite-petite-friendly-finds-from-talbots-2025-fall-collection/': 0.0,
#  'https://awellstyledlife.com/how-to-apply-cream-blush-on-aging-skin-for-a-soft-youthful-flush/': 0.0,
#  'https://awellstyledlife.com/how-to-determine-your-skins-undertone/': 0.0,
#  'https://awellstyledlife.com/how-to-wear-a-blazer-for-fall-2025-outfit-ideas/': 0.0,
#  'https://awellstyledlife.com/makeup-mistakes-that-make-you-look-older/': 0.0,
#  'https://go.shopmy.us/p-25552764': 0.0,
#  'https://go.shopmy.us/p-25553369': 0.0,
#  'https://go.shopmy.us/p-25553623': 0.0,
#  'https://go.shopmy.us/p-25554607': 0.0,
#  'https://go.shopmy.us/p-25555061': 0.0,
#  'https://awellstyledlife.com/a-few-outfits-i-wore-last-week-no-jeans-in-sight/': 0.0,
#  'https://awellstyledlife.com/best-bootcut-jeans-women-over-60/': 0.0,
#  'https://awellstyledlife.com/best-pull-on-jeans-and-pants-for-older-figures/': 0.0,
#  'https://awellstyledlife.com/category/fashion-over-50/fall-fashion/page/10/': 0.0,
#  'https://awellstyledlife.com/category/fashion-over-50/fall-fashion/page/2/': 0.0,
#  'https://awellstyledlife.com/category/fashion/style-tips/page/14/': 0.0,
#  'https://awellstyledlife.com/category/fashion/style-tips/page/2/': 0.0,
#  'https://awellstyledlife.com/category/fashion/style-tips/page/3/': 0.0,
#  'https://awellstyledlife.com/common-shopping-mistakes-women-shopping-tips/': 0.0,
#  'https://awellstyledlife.com/five-things-to-wear-over-50/': 0.0,
#  'https://awellstyledlife.com/how-to-declutter-wardrobe-after-50/': 0.0,
#  'https://awellstyledlife.com/how-to-look-stylish-over-50/': 0.0,
#  'https://awellstyledlife.com/how-to-wear-leggings-after-fifty/': 0.0,
#  'https://awellstyledlife.com/jewelry-rules-women-over-50-over-60/': 0.0,
#  'https://awellstyledlife.com/sleeveless-dress-when-you-dont-love-your-arms/': 0.0,
#  'https://awellstyledlife.com/the-best-color-shoes-to-wear-with-navy-pants/': 0.0,
#  'http://awellstyledlife': 0.0,
#  'http://glenoro.com': 0.0,
#  'http://wellstyledlife.com': 0.0,
#  'http://www.ournewvista.com': 0.0,
#  'https://awellstyledlife.com/how-to-stylishly-tie-and-wear-scarves/comment-page-2/': 0.0,
#  'https://awellstyledlife.com/the-best-new-books-to-read-on-a-winter-vacation/': 0.0,
#  'https://go.shopmy.us/p-34235468': 0.0,
#  'https://readersgather.com/': 0.0,
#  'https://www.highlandsranchfoodie.com': 0.0,
#  'https://awellstyledlife.com/cozy-winter-outfit-ideas-from-walmart/': 0.0,
#  'https://awellstyledlife.com/how-to-wear-brooches-after-50-and-make-them-look-modern/comment-page-2/': 0.0,
#  'https://bit.ly/3mnvcax': 0.0,
#  'https://bit.ly/48p85ji': 0.0,
#  'https://go.shopmy.us/p-18052089': 0.0,
#  'https://go.shopmy.us/p-29509688': 0.0,
#  'https://go.shopmy.us/p-29509763': 0.0,
#  'https://go.shopmy.us/p-32466917': 0.0,
#  'https://go.shopmy.us/p-34800562': 0.0,
#  'https://go.shopmy.us/p-34800956': 0.0,
#  'https://go.shopmy.us/p-34801832': 0.0,
#  'https://go.shopmy.us/p-34801955': 0.0,
#  'https://go.shopmy.us/p-34803757': 0.0,
#  'https://go.shopmy.us/p-34804337': 0.0,
#  'https://go.shopmy.us/p-34805606': 0.0,
#  'https://bestofthislife.com/': 2.9253405456718943e-05,
#  'https://bestofthislife.com/a-hearty-white-bean-and-chicken-chili-from-eat-drink-love/': 2.788946797195891e-06,
#  'https://bestofthislife.com/alltrue-socially-conscious-subscription-box/': 2.083567187540142e-06,
#  'https://bestofthislife.com/dear-readers-heres-to-a-magical-december/': 3.3151823790025608e-06,
#  'https://bestofthislife.com/easy-weekend-brunch-table-setting/': 6.068503943387555e-06,
#  'https://bestofthislife.com/halloween-door-decor-ideas/': 5.116801295439323e-06,
#  'https://bestofthislife.com/our-place-cookware-review/': 7.681818057823862e-06,
#  'https://www.pinterest.ca/emilylynne/': 6.412541905961355e-06,
#  'http://recipeforgoodhealth1.blogspot.com': 0.0,
#  'http://recipeforgoodhealth1.blogspot.com/2014/01/white-bean-soup-with-chicken.html': 0.0,
#  'http://www.bestofthislife.com': 0.0,
#  'http://www.eat-drink-love.com': 0.0,
#  'https://bestofthislife.com/100-things-to-do-at-home-in-december/': 0.0,
#  'https://bestofthislife.com/a-hearty-white-bean-and-chicken-chili-from-eat-drink-love/print/82152/': 0.0,
#  'https://bestofthislife.com/abigail-emery-smith/': 0.0,
#  'https://bestofthislife.com/acorn-squash-stuffed-with-ground-turkey/': 0.0,
#  'https://bestofthislife.com/black-friday-bedroom-furniture-deals-from-wayfair/': 0.0,
#  'https://bestofthislife.com/bloom/': 0.0,
#  'https://bestofthislife.com/budget-friendly-thanksgiving-menu/': 0.0,
#  'https://bestofthislife.com/canadian-foodie-gift-ideas-under-50/': 0.0,
#  'https://bestofthislife.com/category/appetizers/': 0.0,
#  'https://bestofthislife.com/category/bedroom-decor/': 0.0,
#  'https://bestofthislife.com/category/breakfast': 0.0,
#  'https://alltrue.com/': 0.0,
#  'https://bestofthislife.com/8-practical-and-sentimental-graduation-gift-ideas/': 0.0,
#  'https://bestofthislife.com/alpha-hydroxy-orange-exfoliator/': 0.0,
#  'https://bestofthislife.com/category/back-to-school/': 0.0,
#  'https://bestofthislife.com/category/beauty/': 0.0,
#  'https://bestofthislife.com/category/breakfast-recipes/': 0.0,
#  'https://bestofthislife.com/category/crafts/': 0.0,
#  'https://bestofthislife.com/category/crafts/painting-projects/': 0.0,
#  'https://bestofthislife.com/category/cricut/': 0.0,
#  'https://bestofthislife.com/category/dairy-free': 0.0,
#  'https://bestofthislife.com/category/desserts': 0.0,
#  'https://bestofthislife.com/category/desserts/': 0.0,
#  'https://bestofthislife.com/category/diy-decor/': 0.0,
#  'https://bestofthislife.com/category/diy/': 0.0,
#  'https://bestofthislife.com/category/fathers-day/': 0.0,
#  'https://bestofthislife.com/20-gluten-free-christmas-cookie-recipes/': 0.0,
#  'https://bestofthislife.com/5-simple-ways-to-make-your-home-more-hygge/': 0.0,
#  'https://bestofthislife.com/category/christmas-recipe/': 0.0,
#  'https://bestofthislife.com/category/christmas/': 0.0,
#  'https://bestofthislife.com/category/entertaining/': 0.0,
#  'https://bestofthislife.com/category/family/': 0.0,
#  'https://bestofthislife.com/category/gluten-free': 0.0,
#  'https://bestofthislife.com/category/home-decor-accents': 0.0,
#  'https://bestofthislife.com/category/home-for-the-holidays/': 0.0,
#  'https://bestofthislife.com/category/home/': 0.0,
#  'https://bestofthislife.com/category/kids-decor/': 0.0,
#  'https://bestofthislife.com/category/kitchen-decor/': 0.0,
#  'https://bestofthislife.com/category/living-room-decor/': 0.0,
#  'https://bestofthislife.com/category/lunch': 0.0,
#  'https://bestofthislife.com/category/lunch/': 0.0,
#  'http://ladyandtheblog.com': 0.0,
#  'http://toughcookiemommy.com': 0.0,
#  'http://www.ourfamilyworld.com/': 0.0,
#  'http://www.thehappyarkansan.com': 0.0,
#  'https://bestofthislife.com/2016/02/easy-weekend-brunch-table-setting.html/easy-weekend-brunch-table-setting': 0.0,
#  'https://bestofthislife.com/25-delicious-recipes-to-celebrate-canada-day/': 0.0,
#  'https://bestofthislife.com/a-paddington-bear-birthday-party-for-little-a/': 0.0,
#  'https://bestofthislife.com/bunny-butt-sugar-cookies-recipe/': 0.0,
#  'https://bestofthislife.com/caprese-steak/': 0.0,
#  'https://bestofthislife.com/category/canada-day/': 0.0,
#  'https://bestofthislife.com/category/easter/': 0.0,
#  'https://bestofthislife.com/category/entertaining/easter-entertaining/': 0.0,
#  'https://bestofthislife.com/category/entertaining/picnics/': 0.0,
#  'https://bestofthislife.com/category/entertaining/summer-entertaining/': 0.0,
#  'https://bestofthislife.com/category/entertaining/valentines-day-entertaining/': 0.0,
#  'https://bestofthislife.com/7-essential-yoga-poses-for-evening/': 0.0,
#  'https://bestofthislife.com/canadian-home-brands/': 0.0,
#  'https://bestofthislife.com/category/fall-recipe/': 0.0,
#  'https://bestofthislife.com/category/gluten-free/': 0.0,
#  'https://bestofthislife.com/category/halloween/': 0.0,
#  'https://bestofthislife.com/category/home-decor/': 0.0,
#  'https://bestofthislife.com/category/kids-2/': 0.0,
#  'https://bestofthislife.com/category/kids-parties/': 0.0,
#  'https://bestofthislife.com/category/kitchen/': 0.0,
#  'https://bestofthislife.com/category/main-dishes': 0.0,
#  'https://bestofthislife.com/category/main-dishes/': 0.0,
#  'https://bestofthislife.com/category/mothers-day/': 0.0,
#  'https://bestofthislife.com/category/parenting/': 0.0,
#  'https://bestofthislife.com/category/personal-development/': 0.0,
#  'https://bestofthislife.com/category/picnics/': 0.0,
#  'https://bestofthislife.com/best-kids-lunches/': 0.0,
#  'https://bestofthislife.com/best-supplements-for-fall/': 0.0,
#  'https://bestofthislife.com/category/drinks/': 0.0,
#  'https://bestofthislife.com/category/reader-favourites/': 0.0,
#  'https://bestofthislife.com/category/reviews/': 0.0,
#  'https://bestofthislife.com/category/sides': 0.0,
#  'https://bestofthislife.com/category/sides/': 0.0,
#  'https://bestofthislife.com/category/smoothies': 0.0,
#  'https://bestofthislife.com/category/smoothies/': 0.0,
#  'https://bestofthislife.com/category/snacks/': 0.0,
#  'https://bestofthislife.com/category/st-patricks-day/': 0.0,
#  'https://bestofthislife.com/category/thanksgiving/': 0.0,
#  'https://bestofthislife.com/category/valentines-day/': 0.0,
#  'https://bestofthislife.com/category/vegan': 0.0,
#  'https://bestofthislife.com/classic-italian-christmas-cookies-to-bake/': 0.0,
#  'https://www.pinterest.ca/': 0.0,
#  'https://www.pinterest.ca/emilylynne/_created': 0.0,
#  'https://www.pinterest.ca/emilylynne/_saved': 0.0,
#  'https://www.pinterest.ca/emilylynne/dinner-recipes/': 0.0,
#  'https://www.pinterest.ca/emilylynne/easy-lunch-ideas/': 0.0,
#  'https://www.pinterest.ca/emilylynne/favourite-blogger-recipes/': 0.0,
#  'https://www.pinterest.ca/emilylynne/gluten-free-recipes/': 0.0,
#  'https://www.pinterest.ca/emilylynne/instagram/': 0.0,
#  'https://www.pinterest.ca/emilylynne/new-recipes-to-try/': 0.0,
#  'https://www.pinterest.ca/emilylynne/recipes-bestofthislifecom/': 0.0,
#  'https://camillestyles.com/food/cooking/': 0.0,
#  'https://camillestyles.com/food/meal-prep/': 0.0,
#  'https://camillestyles.com/food/recipes/': 0.0,
#  'https://camillestyles.com/food/recipes/breakfast/': 0.0,
#  'https://camillestyles.com/food/winter-weeknight-dinners/': 0.0,
#  'https://camillestyles.com/issues/baby-kale-sweet-potato-winter-salad/': 0.0,
#  'https://camillestyles.com/issues/gluten-free-buckwheat-cardamom-buns/': 0.0,
#  'https://camillestyles.com/magazine-winter-2025': 0.0,
#  'https://camillestyles.com/magazine/': 0.0,
#  'https://camillestyles.com/style/': 0.0,
#  'https://camillestyles.com/style/fashion/': 0.0,
#  'https://camillestyles.com/style/hair/': 0.0,
#  'https://camillestyles.com/style/makeup/': 0.0,
#  'https://camillestyles.com/style/skincare/': 0.0,
#  'https://camillestyles.com/2025-gift-guide/': 0.0,
#  'https://camillestyles.com/food/recipes/sides/': 0.0,
#  'https://camillestyles.com/issues/chestnut-cake/': 0.0,
#  'https://camillestyles.com/issues/gift-guide-under-30/': 0.0,
#  'https://camillestyles.com/style/skincare/ask-a-derm/': 0.0,
#  'https://camillestyles.com/style/trend-report/': 0.0,
#  'https://camillestyles.com/subscribe/': 0.0,
#  'https://camillestyles.com/wellness/': 0.0,
#  'https://camillestyles.com/wellness/books/': 0.0,
#  'https://camillestyles.com/wellness/health/': 0.0,
#  'https://camillestyles.com/wellness/morning-routine/': 0.0,
#  'https://camillestyles.com/wellness/morning-routine/wake-up-call/': 0.0,
#  'https://camillestyles.com/wellness/nutrition/': 0.0,
#  'https://camillestyles.com/wellness/relationships/': 0.0,
#  'https://camillestyles.com/wellness/sleep/': 0.0,
#  'https://camillestyles.com/issues/mimi-thorisson/': 0.0,
#  'https://camillestyles.com/wellness/travel/': 0.0,
#  'https://camillestyles.substack.com/': 0.0,
#  'https://casazuma.com/blogs/journal/ryan-smith': 0.0,
#  'https://casazuma.com/pages/dinner-party': 0.0,
#  'https://casazuma.com': 0.0,
#  'https://camillestyles.com/food/recipes/pastas/brown-butter-pumpkin-ravioli/': 0.0,
#  'https://camillestyles.com/food/recipes/salads/little-gem-persimmon-salad/': 0.0,
#  'https://camillestyles.com/food/recipes/sides/roasted-radicchio-with-manchego/': 0.0,
#  'https://go.shopmy.us/p-30546982': 0.0,
#  'https://go.shopmy.us/p-30547790': 0.0,
#  'https://lavinotheque.com/still-wine/7601-ramon-bilbao-rioja-early-harvest-rosado-750ml.html': 0.0,
#  'https://camillestyles.com/food/recipes/dessert/': 0.0,
#  'https://camillestyles.com/food/recipes/vegetarian/': 0.0,
#  'https://camillestyles.com/issues/ribollita-toscana/': 0.0,
#  'https://camillestyles.com/entertaining/dinner-party-hosting-lessons/': 0.0,
#  'https://camillestyles.com/entertaining/dinner-party-secrets/': 0.0,
#  'https://camillestyles.com/entertaining/how-to-set-a-table/': 0.0,
#  'https://camillestyles.com/entertaining/menu-ideas/dinner-party-menu-ideas/': 0.0,
#  'https://camillestyles.com/entertaining/set-the-table/how-to-set-a-table-with-napkins/': 0.0,
#  'https://camillestyles.com/wellness/how-to-create-a-vision-board/': 0.0,
#  'https://camillestyles.com/wellness/perfectionism-and-anxiety/': 0.0,
#  'https://camillestyles.com/style/2026-beauty-trends/': 0.0,
#  'https://camillestyles.com/style/2026-fashion-trend-predictions/': 0.0,
#  'https://camillestyles.com/style/beauty-tips-40s/': 0.0,
#  'https://camillestyles.com/style/cortisol-and-skin/': 0.0,
#  'https://camillestyles.com/style/desert-island-beauty-products/': 0.0,
#  'https://camillestyles.com/style/holiday-pajamas/': 0.0,
#  'https://camillestyles.com/style/hot-girl-hamster-wheel/': 0.0,
#  'https://camillestyles.com/style/skincare/full-body-red-light-therapy/': 0.0,
#  'https://camillestyles.com/style/winter-skincare-tips/': 0.0,
#  'https://camillestyles.com/wellness/how-to-sleep-better/': 0.0,
#  'https://go.shopmy.us/p-34216399': 0.0,
#  'https://go.shopmy.us/p-34216759': 0.0,
#  'https://go.shopmy.us/p-34217001': 0.0,
#  'https://go.shopmy.us/p-34217273': 0.0,
#  'https://go.shopmy.us/p-34217536': 0.0,
#  'https://camillestyles.com/wellness/breathing-space/gut-healthy-meal-plan/': 0.0,
#  'https://camillestyles.com/wellness/favorite-books-2025/': 0.0,
#  'https://camillestyles.com/wellness/heal-my-gut/': 0.0,
#  'https://camillestyles.com/wellness/january-bucket-list/': 0.0,
#  'https://camillestyles.com/wellness/what-it-takes-to-transform-your-life/': 0.0,
#  'https://camillestyles.substack.com/t/design-your-dream-year': 0.0,
#  'https://caphillstyle.com/': 0.0,
#  'https://caphillstyle.com/capitol/2024/08/26/the-range-suede-flats-for-fall.html': 1.155275406867641e-06,
#  'https://caphillstyle.com/capitol/2024/09/03/three-bold-color-combinations-for-fall.html': 5.13512284374207e-06,
#  'https://caphillstyle.com/capitol/2025/12/29/is-cole-haan-comfortable-again.html': 1.0433103894619666e-06,
#  'https://caphillstyle.com/capitol/category/style/how-to-wear-it': 3.5981485139005383e-06,
#  'https://www.wsj.com/articles/dear-j-crew-what-happened-to-us-we-used-to-be-so-close-1432661954': 0.0,
#  'https://caphillstyle.com/blog': 0.0,
#  'https://caphillstyle.com/blog-archives': 0.0,
#  'https://caphillstyle.com/subscribe': 0.0,
#  'https://abrabelke.substack.com/': 0.0,
#  'https://amzn.to/3yxydk8': 0.0,
#  'https://blairstaky.com': 0.0,
#  'https://caphillstyle.com': 0.0,
#  'https://caphillstyle.com/capitol/2024/08/21/the-find-a-dress-you-will-never-regret.html': 0.0,
#  'https://caphillstyle.com/capitol/2024/08/22/59158.html': 0.0,
#  'https://caphillstyle.com/capitol/2024/08/22/the-range-packable-puffer-jackets.html': 0.0,
#  'https://caphillstyle.com/capitol/2024/08/28/out-of-office-on-vacation.html': 0.0,
#  'https://caphillstyle.com/capitol/category/ask-the-editor': 0.0,
#  'https://caphillstyle.com/capitol/category/beauty': 0.0,
#  'https://caphillstyle.com/capitol/category/features': 0.0,
#  'https://caphillstyle.com/capitol/category/features/range': 0.0,
#  'https://caphillstyle.com/capitol/2024/09/03/the-find-chic-flats-for-fall.html': 0.0,
#  'https://caphillstyle.com/capitol/2024/09/04/five-amazing-fall-handbags.html': 0.0,
#  'https://caphillstyle.com/capitol/category/posts': 0.0,
#  'https://caphillstyle.com/capitol/category/style': 0.0,
#  'https://caphillstyle.com/capitol/category/style/weekend': 0.0,
#  'https://caphillstyle.com/capitol/category/style/work': 0.0,
#  'https://caphillstyle.com/capitol/category/workday-reading': 0.0,
#  'https://flagship.shop/abrabelke': 0.0,
#  'https://go.shopmy.us/p-7453425': 0.0,
#  'https://go.shopmy.us/p-7453466': 0.0,
#  'https://go.shopmy.us/p-7454121': 0.0,
#  'https://go.shopmy.us/p-7454229': 0.0,
#  'https://go.shopmy.us/p-7454236': 0.0,
#  'https://go.shopmy.us/p-7454249': 0.0,
#  'https://go.shopmy.us/p-7454547': 0.0,
#  'https://alexandriashoerepair.com/': 0.0,
#  'https://caphillstyle.com/capitol/2025/12/22/ask-the-editor-vol-v-no-nine.html': 0.0,
#  'https://caphillstyle.com/capitol/2025/12/29/just-one-more-2025-sale-post.html': 0.0,
#  'https://go.shopmy.us/p-36869963': 0.0,
#  'https://go.shopmy.us/p-36871171': 0.0,
#  'https://go.shopmy.us/p-36871345': 0.0,
#  'https://go.shopmy.us/p-36871372': 0.0,
#  'https://mailchi.mp/6c93d3d882b0/subscribe-to-the-work-edit': 0.0,
#  'https://time.com/archive/6641805/bubble-on-the-potomac/': 0.0,
# ...
#  'https://chachingqueen.com/gen-z-money-habits/': 6.719936771929661e-06,
#  'https://chachingqueen.com/habits-making-home-smell-bad/': 6.109218495171437e-06,
#  'https://chachingqueen.com/things-smartphones-have-replaced/': 6.628329030415927e-06,
#  'https://buffer.com/add': 0.0,
#  'https://chachingqueen.com': 0.0,
#  'https://chachingqueen.com/amazon-coupons-discounts-and-deals-promo-codes/': 0.0,
#  'https://chachingqueen.com/amazon-prime-free-trial-watch-free-instant-movies/': 0.0,
#  'https://chachingqueen.com/best-apps-for-cashback/': 0.0,
#  'https://chachingqueen.com/category/diy/': 0.0,
#  'https://chachingqueen.com/category/diy/cleaning/': 0.0,
#  'https://chachingqueen.com/category/diy/crafts/': 0.0,
#  'https://chachingqueen.com/category/diy/home-improvement/': 0.0,
#  'https://chachingqueen.com/category/diy/household-hacks/': 0.0,
#  'https://chachingqueen.com/category/eat/': 0.0,
#  'https://chachingqueen.com/category/eat/appetizers-and-sides/': 0.0,
#  'https://chachingqueen.com/category/eat/breakfast/': 0.0,
#  'https://chachingqueen.com/category/eat/desserts/': 0.0,
#  'https://chachingqueen.com/best-clotheslines/': 0.0,
#  'https://chachingqueen.com/best-way-to-clean-cloth-diapers/': 0.0,
#  'https://chachingqueen.com/category/eat/food-talk/': 0.0,
#  'https://chachingqueen.com/category/eat/lunch-and-dinner/': 0.0,
#  'https://chachingqueen.com/category/life/': 0.0,
#  'https://chachingqueen.com/category/life/cloth-diapers/': 0.0,
#  'https://chachingqueen.com/category/life/family-and-relationships/': 0.0,
#  'https://chachingqueen.com/category/life/health-beauty/': 0.0,
#  'https://chachingqueen.com/category/life/holidays/': 0.0,
#  'https://chachingqueen.com/category/money/': 0.0,
#  'https://chachingqueen.com/category/money/financial-planning/': 0.0,
#  'https://chachingqueen.com/category/money/get-free-stuff/': 0.0,
#  'https://chachingqueen.com/category/money/make-money/': 0.0,
#  'https://chachingqueen.com/category/money/review/': 0.0,
#  'https://chachingqueen.com/category/money/save/': 0.0,
#  'https://chachingqueen.com/benefits-of-financial-planning/': 0.0,
#  'https://chachingqueen.com/category/travel/': 0.0,
#  'https://chachingqueen.com/category/travel/attractions/': 0.0,
#  'https://chachingqueen.com/category/travel/destinations/': 0.0,
#  'https://chachingqueen.com/category/travel/travel-tips/': 0.0,
#  'https://chachingqueen.com/cookie-policy/': 0.0,
#  'https://chachingqueen.com/disclosure/': 0.0,
#  'https://chachingqueen.com/diy-homemade-household-products/': 0.0,
#  'https://chachingqueen.com/financially-ahead-average-american/': 0.0,
#  'https://chachingqueen.com/get-out-of-debt/': 0.0,
#  'https://chachingqueen.com/gift-ideas-for-parents-who-want-nothing/': 0.0,
#  'https://chachingqueen.com/how-often-should-you-be-cleaning-your-home/': 0.0,
#  'https://chachingqueen.com/how-to-budget/': 0.0,
#  'https://chachingqueen.com/how-to-get-started-investing/': 0.0,
#  'https://chachingqueen.com/how-to-retire-early-according-to-dave-ramsey/': 0.0,
#  'https://chachingqueen.com/benefits-of-good-credit-score/': 0.0,
#  'https://chachingqueen.com/best-side-hustles-for-college-students/': 0.0,
#  'https://chachingqueen.com/budgeting-styles/': 0.0,
#  'https://chachingqueen.com/easy-certifications-that-pay-well/': 0.0,
#  'https://chachingqueen.com/financial-moves-for-your-future/': 0.0,
#  'https://chachingqueen.com/financially-literate-states/': 0.0,
#  'https://chachingqueen.com/hidden-credit-card-perks/': 0.0,
#  'https://chachingqueen.com/high-paying-jobs-without-degree/': 0.0,
#  'https://chachingqueen.com/high-return-hidden-businesses/': 0.0,
#  'https://chachingqueen.com/how-to-get-out-of-debt-quickly/': 0.0,
#  'https://chachingqueen.com/how-to-save-on-monthly-bills/': 0.0,
#  'https://chachingqueen.com/improve-financial-situation/': 0.0,
#  'https://chachingqueen.com/make-money-without-job/': 0.0,
#  'https://chachingqueen.com/money-wasting-habits/': 0.0,
#  'https://chachingqueen.com/press/': 0.0,
#  'https://chachingqueen.com/category/galleries/': 0.0,
#  'https://chachingqueen.com/clean-with-toothpaste/': 0.0,
#  'https://chachingqueen.com/cleaning-checklist/': 0.0,
#  'https://chachingqueen.com/common-kitchen-mistakes/': 0.0,
#  'https://chachingqueen.com/common-plumbing-issues/': 0.0,
#  'https://chachingqueen.com/diy-carpet-cleaner/': 0.0,
#  'https://chachingqueen.com/diy-shower-head-cleaner-easy-vinegar/': 0.0,
#  'https://chachingqueen.com/easier-faster-laundry/': 0.0,
#  'https://chachingqueen.com/easy-ways-to-clean-dirty-spots/': 0.0,
#  'https://chachingqueen.com/foods-with-short-life-in-refrigerator/': 0.0,
#  'https://chachingqueen.com/forgotten-cleaning-tip/': 0.0,
#  'https://chachingqueen.com/get-rid-of-pet-odors/': 0.0,
#  'https://chachingqueen.com/household-items-cleaning-hacks/': 0.0,
#  'https://chachingqueen.com/how-to-clean-a-microwave-eight-easy-ways/': 0.0,
#  'https://chachingqueen.com/how-to-clean-refrigerator/': 0.0,
#  'https://chachingqueen.com/childhood-in-the-1960s/': 0.0,
#  'https://chachingqueen.com/coupons-database/': 0.0,
#  'https://chachingqueen.com/professional-cleaning-hacks/': 0.0,
#  'https://chachingqueen.com/spring-cleaning/': 0.0,
#  'https://chachingqueen.com/stop-doing-these-if-over-fifty/': 0.0,
#  'https://chachingqueen.com/stop-doing-these-if-over-sixty/': 0.0,
#  'https://chachingqueen.com/subscribe/': 0.0,
#  'https://chachingqueen.com/things-likely-to-vanish-with-baby-boomers/': 0.0,
#  'https://chachingqueen.com/things-society-has-left-behind/': 0.0,
#  'https://chachingqueen.com/travel-hacks-with-your-phone/': 0.0,
#  'https://chachingqueen.com/web-stories/': 0.0,
#  'https://chachingqueen.com/what-to-teach-kids-about-money/': 0.0,
#  'https://lineit.line.me/share/ui': 0.0,
#  'https://news.ycombinator.com/submitlink': 0.0,
#  'https://share.flipboard.com/bookmarklet/popout': 0.0,
#  'https://coloradomountainmom.com/': 9.343989634400832e-06,
#  'https://coloradomountainmom.com/2012/09/disney-social-media-moms-on-the-road-celebration-in-houston-tx/': 4.31865067136173e-06,
#  'https://coloradomountainmom.com/a-first-timers-guide-to-must-see-venetian-cultural-attractions/': 8.884496835697023e-07,
#  'https://coloradomountainmom.com/dublin-dog-trail-gear-koa-and-all-style-no-stink-collars/': 6.036804756641533e-06,
#  'https://coloradomountainmom.com/effortless-style-for-busy-moms-keeping-stress-levels-low-with-easy-outfits/': 2.4335669237680106e-06,
#  'https://coloradomountainmom.com/healthy-habits-after-vacation-indulgence-a-guide-for-busy-families/': 1.6090972501444076e-06,
#  'https://coloradomountainmom.com/pantry-essentials-every-parent-should-have-for-effortless-family-meals/': 2.006064130037254e-06,
#  'https://coloradomountainmom.com/seasonal-shift-versatile-clothing-pieces-for-year-round-wear/': 2.6778542344712997e-06,
#  'https://coloradomountainmom.com/disney-social-media-moms-on-the-road-celebration-in-houston-tx/': 0.0,
#  'http://disneylovinspectrummom.com/': 0.0,
#  'http://healthydisneyfamily.com': 0.0,
#  'http://www.capturingmagicalmemories.com': 0.0,
#  'http://www.capturingmagicalmemories.com/': 0.0,
#  'http://www.disneysmmoms.com/disney-smmc-on-the-road/': 0.0,
#  'http://www.dreamingofwdw.wordpress.com': 0.0,
#  'http://www.focusedonthemagic.com': 0.0,
#  'http://www.stumbleupon.com/submit': 0.0,
#  'http://www.theworldisabook.com': 0.0,
#  'https://agirlsguidetocars.com/': 0.0,
#  'https://coloradomountainmom.com/1-day-magic-kingdom-itinerary-kids/': 0.0,
#  'https://coloradomountainmom.com/2012/10/conversations-with-coca-cola-blogging-conference-cclp/': 0.0,
#  'https://coloradomountainmom.com/2013/07/disney-worldless-wednesday-disney-on-the-road/': 0.0,
#  'https://coloradomountainmom.com/2015/07/coca-colas-the-art-of-entrepreneurship-event-5by20/': 0.0,
#  'https://coloradomountainmom.com/2015/07/urban-adventure-in-the-2016-hyundai-tucson/': 0.0,
#  'https://coloradomountainmom.com/2017/09/take-me-fishing-walt-disney-world-fishing/': 0.0,
#  'https://coloradomountainmom.com/atlants-world-of-coke-houses-history-fun-and-a-secret/': 0.0,
#  'https://coloradomountainmom.com/category/colorado/': 0.0,
#  'https://coloradomountainmom.com/category/disney/': 0.0,
#  'https://coloradomountainmom.com/category/family-travel/': 0.0,
#  'https://coloradomountainmom.com/category/health-wellness/': 0.0,
#  'https://coloradomountainmom.com/category/lifestyle/': 0.0,
#  'https://coloradomountainmom.com/category/outdoors/': 0.0,
#  'https://coloradomountainmom.com/category/womens-clothing/': 0.0,
#  'https://coloradomountainmom.com/disney-cars-party-ideas-free-printable-disneyside/': 0.0,
#  'https://coloradomountainmom.com/disneys-secret-world-of-arrietty-activity-coloring-sheets-clips/': 0.0,
#  'https://coloradomountainmom.com/everyday-carry-tools-for-adventurous-families/': 0.0,
#  'https://coloradomountainmom.com/family-jackets-affordable-prices-from-free-country/': 0.0,
#  'https://coloradomountainmom.com/luxury-destinations-for-you-and-your-family/': 0.0,
#  'http://mommasweeps.com': 0.0,
#  'http://moosefish.com': 0.0,
#  'http://redefiningperfect.com': 0.0,
#  'http://thetravelingpraters.com': 0.0,
#  'http://www.deannalw.blogspot.com': 0.0,
#  'http://www.dublindog.com': 0.0,
#  'http://www.dublindog.com/collars/all-style-no-stink-collars': 0.0,
#  'http://www.dublindog.com/collars/koa-collars': 0.0,
#  'http://www.rafflecopter.com/rafl/display/f1fd2048/': 0.0,
#  'http://www.teishknits.com': 0.0,
#  'http://www.valinreallife.com': 0.0,
#  'https://coloradomountainmom.com/climbing-mt-garfield-and-losing-my-toenail/': 0.0,
#  'https://coloradomountainmom.com/skin-cosmetic-line-for-women-over-40-boomstick-review/': 0.0,
#  'https://coloradomountainmom.com/stay-grounded-with-earthing-shoes-from-juil/': 0.0,
#  'https://coloradomountainmom.com/zion-vs-bryce-national-park-tips/': 0.0,
#  'https://coloradomountainmom.com/7-perfect-gift-ideas-for-her-on-special-occasions/': 0.0,
#  'https://coloradomountainmom.com/outdoor-woman-gift-guide/': 0.0,
#  'https://coloradomountainmom.com/why-every-mom-needs-a-reliable-pest-exterminator-in-her-contact-list/': 0.0,
#  'https://outdoorfamiliesonline.com/': 0.0,
#  'https://plus.google.com/share': 0.0,
#  'https://www.bloglovin.com/blogs/colorado-mountain-mom-5741861': 0.0,
#  'https://www.goodamerican.com/collections/womens-jeans': 0.0,
#  'https://www.vogue.com/article/streamline-your-wardrobe-streamline-your-life': 0.0,
#  'https://coloradomountainmom.com/5-foods-to-boost-your-immune-system/': 0.0,
#  'https://www.adriannabohrer.com/home/2019/3-reasons-to-have-a-kitchen-dance-party-right-now': 0.0,
#  'https://dianaelizabethblog.com/2-unique-ornament-exchange-party-that-will-make-guests-happy/': 0.0,
#  'https://dianaelizabethblog.com/lunar-new-year-tablescape/': 0.0,
#  'https://dianaelizabethblog.com/ornament-exchange-christmas/': 0.0,
#  'https://dianaelizabethblog.com/the-prettiest-winter-tradition-youll-want-to-start-a-bulb-planting-party/': 0.0,
#  'https://go.shopmy.us/p-34247270': 0.0,
#  'https://go.shopmy.us/p-34247326': 0.0,
#  'https://go.shopmy.us/p-34248277': 0.0,
#  'https://go.shopmy.us/p-34347203': 0.0,
#  'https://www.worldmarket.com/p/season-caviart-black-seaweed-pearls-598691.html': 0.0,
#  'https://freshmommyblog.com/': 2.687160417736187e-06,
#  'https://freshmommyblog.com/creating-the-perfect-cozy-fall-home-our-best-tips-diy-projects-all-in-one-place/': 1.832154830274673e-06,
#  'https://freshmommyblog.com/podcast/': 1.832154830274673e-06,
#  'https://tabithabluecoursecollection.com/': 6.107182767582242e-07,
#  'https://freshmommyblog.com/cdn-cgi/l/email-protection': 0.0,
#  'https://amzn.to/2khbun0': 0.0,
#  'https://freshmommyblog.com/best-bedding/': 0.0,
#  'https://freshmommyblog.com/building-a-beautiful-fall-tablescape/': 0.0,
#  'https://freshmommyblog.com/category/christmas/': 0.0,
#  'https://freshmommyblog.com/category/downloads/': 0.0,
#  'https://freshmommyblog.com/category/essential-oils/': 0.0,
#  'https://freshmommyblog.com/category/food/': 0.0,
#  'https://freshmommyblog.com/category/home-diy/': 0.0,
#  'https://freshmommyblog.com/category/life-coaching/': 0.0,
#  'https://freshmommyblog.com/category/life/': 0.0,
#  'https://freshmommyblog.com/category/life/blue-ridge-mountains-cabin/': 0.0,
#  'https://freshmommyblog.com/category/motherhood/': 0.0,
#  'https://freshmommyblog.com/category/style-beauty/': 0.0,
#  'https://freshmommyblog.com/category/travel/': 0.0,
#  'https://docs.google.com/forms/d/e/1faipqlseuddzisvdzxcxbjxgea2gvkg8m0ty3vcicke0twrnxlm8i9w/viewform': 0.0,
#  'https://freshmommyblog.com/category/podcast/': 0.0,
#  'https://freshmommyblog.com/change-your-life-with-small-steps/': 0.0,
#  'https://freshmommyblog.com/cultivate-courage/': 0.0,
#  'https://freshmommyblog.com/stop-rushing-and-start-living/': 0.0,
#  'https://freshmommyblog.com/ultimate-morning-routine-free-worksheet/': 0.0,
#  'https://open.spotify.com/show/14prputc0cfyvptraoaqbk': 0.0,
#  'https://podcasts.apple.com/us/podcast/radiant-womanhood/id1727137194': 0.0,
#  'https://podcasts.google.com/feed/ahr0chm6ly9mzwvkcy5jyxb0axzhdguuzm0vcmfkawfudc13b21hbmhvb2qv': 0.0,
#  'https://stan.store/tabithablue/p/get-an-organized-life-planning-worksheets-now': 0.0,
#  'https://cookiedatabase.org/tcf/purposes/': 0.0,
#  'https://tabithabluecoursecollection.com': 0.0,
#  'https://tabithabluecoursecollection.com/visionary/': 0.0,
#  'https://tabithabluecoursecollection.com/wp-login.php': 0.0,
#  'https://www.miladesignco.com': 0.0,
#  ...}
